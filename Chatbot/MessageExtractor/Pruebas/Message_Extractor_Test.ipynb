# %% [markdown]
# # Configuración inicial del extractor de mensajes
# Primero se hacen pruebas en el notebook y después se pasa la información relevante a un archivo .py que va a ser ejecutado cada cierto tiempo para ir actualizando con mensajes nuevos

# %%
import requests
from datetime import datetime
import json
import os

# Configurar el token y el ID del canal de Slack
token = "some_api_key"
channel_id = "some_channel_id"  # Reemplaza con el ID del canal correcto

# Configurar los encabezados de la solicitud
headers = {
    "Authorization": f"Bearer {token}"
}

# DEFINICION DE FUNCIONES
# Función para almacenar y leer el último timestamp
def get_last_timestamp(file_path="last_timestamp.json"):
    try:
        with open(file_path, 'r', encoding = 'utf8') as f:
            data = json.load(f)
            return data.get('last_timestamp', None)
    except FileNotFoundError:
        return None

def save_last_timestamp(timestamp, file_path="last_timestamp.json"):
    with open(file_path, 'w', encoding = 'utf8') as f:
        json.dump({'last_timestamp': timestamp}, f, ensure_ascii = False)

# Función para extraer mensajes del canal de Slack
def fetch_messages(oldest_timestamp=None, oldest = None, latest = None):
    url = f"https://slack.com/api/conversations.history?channel={channel_id}"

    if oldest_timestamp:
        url += f"&oldest={oldest_timestamp}"
    if oldest:
        oldest_ts = datetime.strptime(oldest, "%Y-%m-%d %H:%M:%S").timestamp()
        url += f"&oldest={oldest_ts}"
    if latest:
        latest_ts = datetime.strptime(latest, "%Y-%m-%d %H:%M:%S").timestamp()
        url += f"&latest={latest_ts}"

    response = requests.get(url, headers=headers)

    # Verificar si la solicitud fue exitosa
    if response.status_code != 200:
        print("Error al obtener mensajes:", response.status_code, response.text)
        return []

    data = response.json()

    # Verificar si la respuesta contiene 'messages'
    if not data.get('ok'):
        print("Error:", data.get('error'))
        return []

    return data["messages"]


# Función para obtener respuestas de un hilo
def fetch_thread_messages(thread_ts):
    url = f"https://slack.com/api/conversations.replies?channel={channel_id}&ts={thread_ts}"
    response = requests.get(url, headers=headers)

    # Verificar si la solicitud fue exitosa
    if response.status_code != 200:
        print("Error al obtener mensajes del hilo:", response.status_code, response.text)
        return []

    data = response.json()

    # Verificar si la respuesta contiene 'messages'
    if not data.get('ok'):
        print("Error:", data.get('error'))
        return []

    # Ignorar el primer mensaje ya que es el mensaje principal
    return data["messages"] # return data["messages"][1:]


# Función para obtener la información del usuario
def get_user_info(user_id):
    url = f"https://slack.com/api/users.info?user={user_id}"
    response = requests.get(url, headers=headers)

    # Verificar si la solicitud fue exitosa
    if response.status_code != 200:
        print(f"Error al obtener información del usuario {user_id}:", response.status_code, response.text)
        return None

    data = response.json()

    # Verificar si la respuesta contiene 'user'
    if not data.get('ok'):
        print(f"Error al obtener información del usuario {user_id}:", data.get('error'))
        return None

    return data["user"]

# Función para verificar si un mensaje es una pregunta
def is_question(message_text):
    return message_text.endswith('?') or any(word in message_text.lower() for word in ['qué', 'cuál', 'dónde', 'cuándo', 'por qué', 'cómo'])

# Función para verificar si un mensaje contiene archivos
def contains_files(message):
    return 'files' in message or 'attachments' in message

# Función para procesar y almacenar mensajes en un archivo histórico
def process_and_store_messages(messages, history_file="message_history.json"):
    user_cache = {}
    historical_data = []

    # Leer el archivo histórico si existe
    if os.path.exists(history_file):
        with open(history_file, 'r', encoding = 'utf8') as f:
            historical_data = json.load(f)

    # Procesar y almacenar los mensajes
    for message in messages:
        user_id = message.get('user')
        client_msg_id = message.get('client_msg_id')
        text = message.get('text')
        if text.strip() == '':
          continue  # Ignorar mensajes vacios
        timestamp = message.get('ts')

        # Convertir el timestamp a un formato legible
        dt_object = datetime.fromtimestamp(float(timestamp))
        formatted_time = dt_object.strftime('%Y-%m-%d %H:%M:%S')

        # Obtener información del usuario, utilizando el cache si ya se ha consultado
        if user_id not in user_cache:
            user_info = get_user_info(user_id)
            if user_info:
                user_cache[user_id] = user_info.get('real_name', 'Unknown User')
            else:
                user_cache[user_id] = 'Unknown User'

        user_name = user_cache[user_id]


        # Identificar tipo de mensaje
        message_type = "other"
        if is_question(text):
            message_type = "question"
        elif 'thread_ts' in message:
            message_type = "thread_start"
        elif contains_files(message):
            message_type = "files"
            # continue  # Ignorar mensajes con imágenes

        # Agregar el mensaje al archivo histórico
        historical_data.append({
            'user_id': user_id,
            'client_msg_id': client_msg_id,
            'user_name': user_name,
            'text': text,
            'timestamp': formatted_time,
            'type': message_type,
            'thread_start_msg_id': None
        })


        # Si el mensaje tiene un hilo, obtener los mensajes del hilo
        if 'thread_ts' in message:
            thread_messages = fetch_thread_messages(message['thread_ts'])
            thread_start_msg_id = thread_messages[0].get('client_msg_id')
            for thread_message in thread_messages[1:]:
                user_id = thread_message.get('user')
                client_msg_id = thread_message.get('client_msg_id')
                text = thread_message.get('text')
                if text.strip() == '':
                  continue # Ignorar mensajes vacios
                timestamp = thread_message.get('ts')

                # Convertir el timestamp a un formato legible
                dt_object = datetime.fromtimestamp(float(timestamp))
                formatted_time = dt_object.strftime('%Y-%m-%d %H:%M:%S')

                # Obtener información del usuario, utilizando el cache si ya se ha consultado
                if user_id not in user_cache:
                    user_info = get_user_info(user_id)
                    if user_info:
                        user_cache[user_id] = user_info.get('real_name', 'Unknown User')
                    else:
                        user_cache[user_id] = 'Unknown User'

                user_name = user_cache[user_id]

                # Identificar tipo de mensaje en el hilo
                message_type = "other"
                if is_question(text):
                    message_type = "question"
                elif contains_files(thread_message):
                    message_type = "files"
                    # continue  # Ignorar mensajes con imágenes
                else:
                    message_type = "response"

                # Agregar el mensaje del hilo al archivo histórico
                historical_data.append({
                    'user_id': user_id,
                    'client_msg_id': client_msg_id,
                    'user_name': user_name,
                    'text': text,
                    'timestamp': formatted_time,
                    'type': message_type,
                    'thread_start_msg_id': thread_start_msg_id
                })

    # Guardar el archivo histórico actualizado
    with open(history_file, 'w', encoding = 'utf8') as f:
        json.dump(historical_data, f, indent=4, ensure_ascii = False)

# Eliminacion de mensajes duplicados
def remove_duplicates(history_file="message_history.json"):
    try:
        # Leer el archivo histórico
        with open(history_file, 'r', encoding = 'utf8') as f:
            historical_data = json.load(f)
    except FileNotFoundError:
        print(f"Archivo {history_file} no encontrado.")
        return

    # Utilizar un conjunto para rastrear los mensajes únicos
    unique_messages = []
    seen_messages = set()

    for message in historical_data:
        message_tuple = (message['user_id'], message['client_msg_id'], message['user_name'], message['text'],
                         message['timestamp'], message['type'], message['thread_start_msg_id'])
        if message_tuple not in seen_messages:
            seen_messages.add(message_tuple)
            unique_messages.append(message)

    # Guardar el archivo histórico actualizado sin duplicados
    with open(history_file, 'w', encoding = 'utf8') as f:
        json.dump(unique_messages, f, indent=4, ensure_ascii = False)

    print(f"Se eliminaron duplicados. {len(historical_data) - len(unique_messages)} mensajes eliminados.")

# %%
# EXTRACCION DEL MENSAJE
# Extraer y procesar los mensajes
last_timestamp = get_last_timestamp()  # Obtener el último timestamp procesado
messages = fetch_messages(oldest_timestamp=last_timestamp)  # Extraer mensajes desde el último timestamp
if messages:
    process_and_store_messages(messages)  # Procesar y almacenar los mensajes
    # Guardar el timestamp del último mensaje procesado
    save_last_timestamp(messages[0]['ts'])

# Eliminar duplicados del archivo histórico
remove_duplicates()
# Out:
# Se eliminaron duplicados. 2 mensajes eliminados.

# %%
messages
# Out:
# [{'user': 'U01L6UML92A',
#   'type': 'message',
#   'ts': '1717517037.769309',
#   'client_msg_id': 'a5cb71c3-9a99-4948-ab5f-5222d6c8512a',
#   'text': '<!channel> buenos días, acabo de hacer un ajuste en botmaker para cuando envían un template y la NE responde y le salta el bot de home, ya no debería suceder, por favor me cuentan si sigue la novedad o ya se corrige.',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717517037.769309',
#   'reply_count': 7,
#   'reply_users_count': 3,
#   'latest_reply': '1717518556.170649',
#   'reply_users': ['U05MSA7EBT5', 'U01L6UML92A', 'U01M3018BTP'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'bQZEd',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text',
#         'text': ' buenos días, acabo de hacer un ajuste en botmaker para cuando envían un template y la NE responde y le salta el bot de home, ya no debería suceder, por favor me cuentan si sigue la novedad o ya se corrige.'}]}]}]},
#  {'subtype': 'channel_join',
#   'user': 'U074KB2A2JZ',
#   'text': '<@U074KB2A2JZ> se unió al canal',
#   'inviter': 'U01L6UML92A',
#   'type': 'message',
#   'ts': '1717516479.437239'},
#  {'user': 'U01L6UML92A',
#   'type': 'message',
#   'ts': '1717516471.722849',
#   'client_msg_id': 'b0b3281d-ee99-4e46-8d64-4158bff730d9',
#   'text': '<@U074KB2A2JZ>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'z6Ind',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U074KB2A2JZ'}]}]}]},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717516010.101379',
#   'client_msg_id': 'ad669167-1459-4105-830c-edc6201b2198',
#   'text': '<@U05QZNBJPSR> hola ! en c9 tenemos doble puntaje por tv?',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717516010.101379',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1717516039.173389',
#   'reply_users': ['U05QZNBJPSR'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Kr/lQ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U05QZNBJPSR'},
#        {'type': 'text',
#         'text': ' hola ! en c9 tenemos doble puntaje por tv?'}]}]}]},
#  {'user': 'U065NUTL84A',
#   'type': 'message',
#   'ts': '1717512204.298839',
#   'client_msg_id': 'd77565e0-49c8-4657-8b4b-d4a670255038',
#   'text': 'Buenos días:hugging_face:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'RrXJ0',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días'},
#        {'type': 'emoji', 'name': 'hugging_face', 'unicode': '1f917'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U01L71AMFPG'],
#     'count': 1}]},
#  {'user': 'U01L71AMFPG',
#   'type': 'message',
#   'ts': '1717509951.972829',
#   'client_msg_id': '1ab6eb28-1400-4594-81e5-bba3ee1c3e3c',
#   'text': '<@U062B84FXJB> <@U05R1HSKN80>\nDebido a la caída de Bancolombia de ayer, vamos a hacer el cierre en horas de la tarde, dando tiempo a que nos ingresen más pagos. Para los que tenemos en recuperacion por favor.',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'bHdnJ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U062B84FXJB'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'user', 'user_id': 'U05R1HSKN80'},
#        {'type': 'text',
#         'text': '\nDebido a la caída de Bancolombia de ayer, vamos a hacer el cierre en horas de la tarde, dando tiempo a que nos ingresen más pagos. Para los que tenemos en recuperacion por favor.'}]}]}],
#   'reactions': [{'name': 'raised_hands',
#     'users': ['U062B84FXJB', 'U05MSA7EBT5'],
#     'count': 2},
#    {'name': 'white_check_mark',
#     'users': ['U05R1HSKN80', 'U065NUTL84A'],
#     'count': 2}]},
#  {'text': '<@U04229KLR6E> <@U01L6UML92A> Chicos buenos dìas, es que siempre que envio un mensaje a la NE desde CRM el bot responde de manera antomatica',
#   'files': [{'id': 'F076H400WBC',
#     'created': 1717509947,
#     'timestamp': 1717509947,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U01M3018BTP',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 33928,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F076H400WBC/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F076H400WBC/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076H400WBC-a148af6ddc/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076H400WBC-a148af6ddc/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076H400WBC-a148af6ddc/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 223,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076H400WBC-a148af6ddc/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 298,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076H400WBC-a148af6ddc/image_160.png',
#     'original_w': 638,
#     'original_h': 396,
#     'thumb_tiny': 'AwAdADDRJwaTd70h60lIB273o3e9NwKMCi4h273oLEKSoyR2ptOXvzihMAOcnijJ9KWjNMYzFLg0+igBmDSrkE0m7jOBTlO4H6miwH//2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U01M3018BTP/F076H400WBC/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F076H400WBC-54e583d120',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U01M3018BTP',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'DgnrM',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U04229KLR6E'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'user', 'user_id': 'U01L6UML92A'},
#        {'type': 'text',
#         'text': ' Chicos buenos dìas, es que siempre que envio un mensaje a la NE desde CRM el bot responde de manera antomatica'}]}]}],
#   'type': 'message',
#   'ts': '1717509949.328979',
#   'client_msg_id': '25400a4c-cc9b-4b90-a47e-7f429a527968',
#   'thread_ts': '1717509949.328979',
#   'reply_count': 26,
#   'reply_users_count': 4,
#   'latest_reply': '1717516766.614109',
#   'reply_users': ['U05MSA7EBT5', 'U01L6UML92A', 'U01M3018BTP', 'U05R1HSKN80'],
#   'is_locked': False,
#   'subscribed': False},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717509938.380069',
#   'client_msg_id': '36f167c9-c5b8-4cd4-a997-265f983aebae',
#   'text': '<https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3D1a28c328-97c7-0ee1-011b-64dcfb9e19ff|https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3D1a28c328-97c7-0ee1-011b-64dcfb9e19ff> NE proyectada C9 hace 4 dìas',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717509938.380069',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1717509961.099469',
#   'reply_users': ['U01M3018BTP'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'rBvVT',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'link',
#         'url': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3D1a28c328-97c7-0ee1-011b-64dcfb9e19ff',
#         'text': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3D1a28c328-97c7-0ee1-011b-64dcfb9e19ff'},
#        {'type': 'text', 'text': ' NE proyectada C9 hace 4 dìas'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717509750.974779',
#   'client_msg_id': '10f393c7-0e96-4266-9436-c893e8d6bd38',
#   'text': 'Buenos días :sunny:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'p7YS1',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'sunny', 'unicode': '2600-fe0f'}]}]}]},
#  {'text': '<https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3D1409748c-7293-f981-e38a-65dca7b2c279|https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3D1409748c-7293-f981-e38a-65dca7b2c279> esta NE ya estaba tipificada que no desea acompañamiento',
#   'files': [{'id': 'F0762BPTBV5',
#     'created': 1717508512,
#     'timestamp': 1717508512,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U01M3018BTP',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 5385,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F0762BPTBV5/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F0762BPTBV5/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 17,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 22,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 33,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 37,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0762BPTBV5-c10ab8722e/image_960.png',
#     'thumb_960_w': 960,
#     'thumb_960_h': 44,
#     'original_w': 1017,
#     'original_h': 47,
#     'thumb_tiny': 'AwACADDR70d6O9HegANHalNHagBO1Nl+5Tu1Nl+5QB//2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U01M3018BTP/F0762BPTBV5/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F0762BPTBV5-66ef38f380',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U01M3018BTP',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'B7kI6',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'link',
#         'url': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3D1409748c-7293-f981-e38a-65dca7b2c279',
#         'text': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3D1409748c-7293-f981-e38a-65dca7b2c279'},
#        {'type': 'text',
#         'text': ' esta NE ya estaba tipificada que no desea acompañamiento'}]}]}],
#   'type': 'message',
#   'ts': '1717508514.223179',
#   'client_msg_id': 'b6703e08-1ff7-49b1-b27b-1077424f8af7'},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717508190.415539',
#   'client_msg_id': '5514d6df-a469-4216-9364-5f03df6c6a5d',
#   'text': 'SII',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'EBN5p',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'SII'}]}]}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717508134.454749',
#   'client_msg_id': '4bb18929-e489-48e6-9c12-0b6b8df716e0',
#   'text': 'Ya me ingresaron',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NUtkR',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Ya me ingresaron'}]}]}]},
#  {'user': 'U05QZNBJPSR',
#   'type': 'message',
#   'ts': '1717507832.826689',
#   'client_msg_id': 'beea18a1-ee11-4222-82e5-c8715b19300f',
#   'text': '*<!channel>*  ¡Hola equipo! :star2:\n¡Feliz inicio de mes y de ciclo 9! :tada: Es el momento perfecto para recargar nuestras energías y enfocarnos en nuestros objetivos. Este mes, nuestro propósito es claro: _cerrar muchas ventas, aumentar nuestra efectividad y lograr que el ticket promedio crezca significativamente._ :muscle:\nPara lograrlo, recordemos la importancia de los acuerdos de entendimiento. :handshake: Conocer las motivaciones de nuestros clientes nos permitirá ofrecerles exactamente lo que necesitan y superar sus expectativas. :star2:\nVamos a darla toda y superar los retos que se nos presenten. :boom: Cada uno de nosotrxs tiene la capacidad de hacer la diferencia y juntxs, alcanzaremos nuestros objetivos. ¡Vamos con toda la energía y entusiasmo para que este ciclo sea el mejor! :rocket:\n\n_Reaccionen con un emoji lxs que nos sumamos a este reto de Ciclo 9_ :raised_hands:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'HUPDt',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast',
#         'range': 'channel',
#         'style': {'bold': True}},
#        {'type': 'text', 'text': '  ¡Hola equipo! '},
#        {'type': 'emoji', 'name': 'star2', 'unicode': '1f31f'},
#        {'type': 'text', 'text': '\n¡Feliz inicio de mes y de ciclo 9! '},
#        {'type': 'emoji', 'name': 'tada', 'unicode': '1f389'},
#        {'type': 'text',
#         'text': ' Es el momento perfecto para recargar nuestras energías y enfocarnos en nuestros objetivos. Este mes, nuestro propósito es claro: '},
#        {'type': 'text',
#         'text': 'cerrar muchas ventas, aumentar nuestra efectividad y lograr que el ticket promedio crezca significativamente. ',
#         'style': {'italic': True}},
#        {'type': 'emoji',
#         'name': 'muscle',
#         'unicode': '1f4aa',
#         'style': {'italic': True}},
#        {'type': 'text',
#         'text': '\nPara lograrlo, recordemos la importancia de los acuerdos de entendimiento. '},
#        {'type': 'emoji', 'name': 'handshake', 'unicode': '1f91d'},
#        {'type': 'text',
#         'text': ' Conocer las motivaciones de nuestros clientes nos permitirá ofrecerles exactamente lo que necesitan y superar sus expectativas. '},
#        {'type': 'emoji', 'name': 'star2', 'unicode': '1f31f'},
#        {'type': 'text',
#         'text': '\nVamos a darla toda y superar los retos que se nos presenten. '},
#        {'type': 'emoji', 'name': 'boom', 'unicode': '1f4a5'},
#        {'type': 'text',
#         'text': ' Cada uno de nosotrxs tiene la capacidad de hacer la diferencia y juntxs, alcanzaremos nuestros objetivos. ¡Vamos con toda la energía y entusiasmo para que este ciclo sea el mejor! '},
#        {'type': 'emoji', 'name': 'rocket', 'unicode': '1f680'},
#        {'type': 'text', 'text': '\n\n'},
#        {'type': 'text',
#         'text': 'Reaccionen con un emoji lxs que nos sumamos a este reto de Ciclo 9',
#         'style': {'italic': True}},
#        {'type': 'text', 'text': ' '},
#        {'type': 'emoji', 'name': 'raised_hands', 'unicode': '1f64c'}]}]}],
#   'reactions': [{'name': 'raised_hands',
#     'users': ['U05MSD5TYP5', 'U062B84FXJB'],
#     'count': 2},
#    {'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U03KUR8GFR8'],
#     'count': 2},
#    {'name': 'raised_hands::skin-tone-2',
#     'users': ['U05AA7W7NR3'],
#     'count': 1}]},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717507665.744259',
#   'client_msg_id': '2daada7c-cf8c-47f1-9724-4a4f423e7374',
#   'text': 'X2',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '9WivL',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'X2'}]}]}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717507652.880859',
#   'client_msg_id': '736bb049-c59d-4301-a708-e4e678ed23cb',
#   'text': 'Sin llamadas Ext. 713. Cierre intermedio.',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'waB5o',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Sin llamadas Ext. 713. Cierre intermedio.'}]}]}],
#   'reactions': [{'name': 'point_up_2', 'users': ['U01M3018BTP'], 'count': 1}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717507179.589629',
#   'client_msg_id': '57e78beb-c383-4d7e-ba07-a22f48cefb14',
#   'text': 'Buenos días :heart_hands:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 's6L46',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'heart_hands', 'unicode': '1faf6'}]}]}]},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717506238.197999',
#   'client_msg_id': 'd0c7b7b8-28f8-4d05-a832-7178a205958c',
#   'text': 'Buenos días :sun_with_face:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Zb1H/',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'sun_with_face', 'unicode': '1f31e'}]}]}],
#   'reactions': [{'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U01L71AMFPG'],
#     'count': 2}]},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717506209.954049',
#   'client_msg_id': '87f8d2a3-548f-48f8-ae5f-af8a3fb25932',
#   'text': 'Buenos dìas',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'jHuxV',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos dìas'}]}]}],
#   'reactions': [{'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U01L71AMFPG'],
#     'count': 2}]},
#  {'text': 'Les comparto el plan de trabajo de hoy.\nTambien les cuento que en el transcurso del día se estarán haciendo las actualizaciones de MG y fechas de toma de pedido, por favor guíense por las fechas de 360.',
#   'files': [{'id': 'F076DL6P3QD',
#     'created': 1717505126,
#     'timestamp': 1717505126,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U01L71AMFPG',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 26564,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F076DL6P3QD/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F076DL6P3QD/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076DL6P3QD-ccada88045/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076DL6P3QD-ccada88045/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076DL6P3QD-ccada88045/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 175,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076DL6P3QD-ccada88045/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 233,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F076DL6P3QD-ccada88045/image_160.png',
#     'original_w': 577,
#     'original_h': 280,
#     'thumb_tiny': 'AwAXADC1MvIojAUfWi4BJXApIwQhzxUuEXuF2PDfMeKXPpj8aiB5zSyLk9M0KEUwbHgkdxSByfSotnPC0io3pVcq7i1LEh6VVuJJFZQhwNtWJO1Vrj7y/Soe5tT3IRLN/eNW7R3ZW3nJzVMdat2v3W+tJmk7cuxZyKTjFJR2pWMD/9k=',
#     'permalink': 'https://somoslikeu.slack.com/files/U01L71AMFPG/F076DL6P3QD/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F076DL6P3QD-a34091ffc1',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U01L71AMFPG',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'O0Lff',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Les comparto el plan de trabajo de hoy.\nTambien les cuento que en el transcurso del día se estarán haciendo las actualizaciones de MG y fechas de toma de pedido, por favor guíense por las fechas de 360.'}]}]}],
#   'type': 'message',
#   'ts': '1717506060.631509',
#   'client_msg_id': 'fc525172-918f-42fd-bc03-7751f28beb46'},
#  {'user': 'U01L71AMFPG',
#   'type': 'message',
#   'ts': '1717506007.466109',
#   'client_msg_id': '0f7c9f02-e878-4eee-909d-1789e7e26c85',
#   'text': 'Linda Semana para todas!\nQue empiece ciclo 9!!!! :triangular_flag_on_post:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'tWdcs',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Linda Semana para todas!\nQue empiece ciclo 9!!!! '},
#        {'type': 'emoji',
#         'name': 'triangular_flag_on_post',
#         'unicode': '1f6a9'}]}]}],
#   'reactions': [{'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U05AA7W7NR3'],
#     'count': 2}]},
#  {'user': 'U03KUR8GFR8',
#   'type': 'message',
#   'ts': '1717505850.064689',
#   'client_msg_id': 'ff5491fc-efd1-4b49-bc33-ab4c0aaa2a66',
#   'text': 'Buenos días!!',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'L34Jw',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días!!'}]}]}],
#   'reactions': [{'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U01L71AMFPG'],
#     'count': 2}]},
#  {'user': 'U01M3018BTP',
#   'type': 'message',
#   'ts': '1717505781.246179',
#   'client_msg_id': 'fc9ed45b-240f-4883-a823-f70285386939',
#   'text': 'Buen día :sunflower:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'UZDWA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buen día '},
#        {'type': 'emoji', 'name': 'sunflower', 'unicode': '1f33b'}]}]}],
#   'reactions': [{'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U01L71AMFPG'],
#     'count': 2}]},
#  {'user': 'U062B84FXJB',
#   'type': 'message',
#   'ts': '1717505724.873509',
#   'client_msg_id': 'df9af59e-28e2-4475-9fec-6b86167b541d',
#   'text': 'Buuuuenos días compañeras :blue_heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '5NVH8',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buuuuenos días compañeras '},
#        {'type': 'emoji', 'name': 'blue_heart', 'unicode': '1f499'}]}]}],
#   'reactions': [{'name': 'unicorn_face',
#     'users': ['U05MSA7EBT5', 'U01L71AMFPG'],
#     'count': 2}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717265829.265029',
#   'client_msg_id': 'f5201d79-f060-40e4-81fc-0021224d72af',
#   'text': 'Break',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'DTxwR',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Break'}]}]}]},
#  {'user': 'U065NUTL84A',
#   'type': 'message',
#   'ts': '1717260733.588039',
#   'client_msg_id': '4b16cd78-b1ce-4b62-ad76-5f5d01d3a46d',
#   'text': 'Feliz fin de semana aprovechen a descansar :heart_hands:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'TjdNA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Feliz fin de semana aprovechen a descansar '},
#        {'type': 'emoji', 'name': 'heart_hands', 'unicode': '1faf6'}]}]}],
#   'reactions': [{'name': 'dizzy',
#     'users': ['U05R1HSKN80', 'U05MSA7EBT5'],
#     'count': 2}]},
#  {'user': 'U062B84FXJB',
#   'type': 'message',
#   'ts': '1717258965.218219',
#   'edited': {'user': 'U062B84FXJB', 'ts': '1717258980.000000'},
#   'client_msg_id': '615a4593-16b1-4630-a301-689e0516a0d4',
#   'text': 'Feliz fin de semana compañeras:blue_heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'WdMWS',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Feliz fin de semana compañeras'},
#        {'type': 'emoji', 'name': 'blue_heart', 'unicode': '1f499'}]}]}],
#   'reactions': [{'name': 'heart_hands::skin-tone-2',
#     'users': ['U05AA7W7NR3'],
#     'count': 1},
#    {'name': 'heart_hands',
#     'users': ['U03KUR8GFR8', 'U065NUTL84A', 'U05MSA7EBT5'],
#     'count': 3},
#    {'name': 'dizzy', 'users': ['U05R1HSKN80', 'U05MSA7EBT5'], 'count': 2}]},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717257171.560509',
#   'client_msg_id': 'cc72249f-3e28-4e20-85db-12d381ceb693',
#   'text': 'niñas, saben si el black day y doble puntos por tv se amplió hasta el 3 de Junio?',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717257171.560509',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1717257330.889179',
#   'reply_users': ['U05MSA7EBT5'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'qzIDg',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'niñas, saben si el black day y doble puntos por tv se amplió hasta el 3 de Junio?'}]}]}]},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717256237.277939',
#   'client_msg_id': '3b99c347-6aeb-430f-b420-65e6c18ebccf',
#   'text': 'Buenos días :sun_with_face:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Zb1H/',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'sun_with_face', 'unicode': '1f31e'}]}]}],
#   'reactions': [{'name': 'heart',
#     'users': ['U065NUTL84A',
#      'U05MSD5TYP5',
#      'U05AA7W7NR3',
#      'U01L71AMFPG',
#      'U05MSA7EBT5'],
#     'count': 5}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717254011.009569',
#   'client_msg_id': '38788458-f2b5-4b9b-a772-b5603a43751e',
#   'text': '<@U01L71AMFPG> Hola Pao, 68248092 No conoce a la NE, ya estaba tipificado antes igual',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NUTu4',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' Hola Pao, 68248092 No conoce a la NE, ya estaba tipificado antes igual'}]}]}],
#   'reactions': [{'name': 'eyes', 'users': ['U01L71AMFPG'], 'count': 1}]},
#  {'text': 'Niñas para infórmales que el pago en punto físico Bancolombia por TV esta deshabilitado por cierre de ciclo, se activa nuevamente el 04/06/2024!! pagos solo por PSE Y Wompi',
#   'files': [{'id': 'F0766T6TQ1J',
#     'created': 1717251756,
#     'timestamp': 1717251756,
#     'name': 'TV.png',
#     'title': 'TV.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U05MSD5TYP5',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 39208,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F0766T6TQ1J/tv.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F0766T6TQ1J/download/tv.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 130,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 174,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 261,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 289,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_960.png',
#     'thumb_960_w': 960,
#     'thumb_960_h': 347,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F0766T6TQ1J-d6e63cb3ba/tv_1024.png',
#     'thumb_1024_w': 1024,
#     'thumb_1024_h': 371,
#     'original_w': 1075,
#     'original_h': 389,
#     'thumb_tiny': 'AwARADDRJ46Um4en6UtHegABB7fpTd6f3l/Ong+tRIwCgENn6GgB29P7y/nSh0JwCpNJvH+1/wB8mkLBioAP3vQ0APooooAKKKKACiiigD//2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U05MSD5TYP5/F0766T6TQ1J/tv.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F0766T6TQ1J-ccc47bbdba',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U05MSD5TYP5',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'svypD',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Niñas para infórmales que el pago en punto físico Bancolombia por TV esta deshabilitado por cierre de ciclo, se activa nuevamente el 04/06/2024!! pagos solo por PSE Y Wompi'}]}]}],
#   'type': 'message',
#   'ts': '1717251844.776349',
#   'client_msg_id': 'a095f200-aeee-4fbc-bdb6-59e6a38a9849',
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U05MSA7EBT5', 'U065NUTL84A', 'U05AA7W7NR3'],
#     'count': 3}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717250551.329189',
#   'client_msg_id': '73c976e9-8ba4-4f11-9fca-b04622ad9cae',
#   'text': 'Buenos días :sunny:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'p7YS1',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'sunny', 'unicode': '2600-fe0f'}]}]}],
#   'reactions': [{'name': 'hearts',
#     'users': ['U065NUTL84A', 'U062B84FXJB', 'U05MSA7EBT5', 'U01L71AMFPG'],
#     'count': 4}]},
#  {'user': 'U01L71AMFPG',
#   'type': 'message',
#   'ts': '1717249993.411819',
#   'client_msg_id': 'a7e1dc29-b8b2-4a9d-b939-d3935edc0c34',
#   'text': 'Hoy no deberían ya salir casos de NE que no pertenecen pero si les sale estaré atenta.',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '+gJHA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hoy no deberían ya salir casos de NE que no pertenecen pero si les sale estaré atenta.'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U05MSD5TYP5',
#      'U05AA7W7NR3',
#      'U05MSA7EBT5',
#      'U062B84FXJB',
#      'U065NUTL84A'],
#     'count': 5}]},
#  {'user': 'U01L71AMFPG',
#   'type': 'message',
#   'ts': '1717249902.651149',
#   'client_msg_id': 'b945676f-b3df-40f0-8436-824d43c3451a',
#   'text': 'Hola buenos días a todas... Hoy olvidé saludar temprano :face_with_peeking_eye: .\nQue tengan un junio maravilloso.',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'DW5A2',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hola buenos días a todas... Hoy olvidé saludar temprano '},
#        {'type': 'emoji', 'name': 'face_with_peeking_eye', 'unicode': '1fae3'},
#        {'type': 'text', 'text': ' .\nQue tengan un junio maravilloso.'}]}]}],
#   'reactions': [{'name': 'sunflower',
#     'users': ['U01M3018BTP',
#      'U05MSD5TYP5',
#      'U05AA7W7NR3',
#      'U05MSA7EBT5',
#      'U065NUTL84A'],
#     'count': 5}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717248760.350589',
#   'client_msg_id': 'e40adec3-4af1-411b-80fc-07e574479355',
#   'text': ':heart_hands:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '4Ww7N',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji',
#         'name': 'heart_hands',
#         'unicode': '1faf6'}]}]}],
#   'reactions': [{'name': 'purple_heart',
#     'users': ['U05MSD5TYP5',
#      'U01M3018BTP',
#      'U065NUTL84A',
#      'U01L71AMFPG',
#      'U05AA7W7NR3',
#      'U062B84FXJB'],
#     'count': 6}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717248753.834589',
#   'client_msg_id': '70d3c78c-5f83-4617-8ffa-3cde86440147',
#   'text': 'Buenos días',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'uqcJp',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días'}]}]}]},
#  {'user': 'U01M3018BTP',
#   'type': 'message',
#   'ts': '1717248731.031249',
#   'client_msg_id': '350d4eba-351a-45ca-8de1-ed270938b06e',
#   'text': 'Buen día :sunflower:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'UZDWA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buen día '},
#        {'type': 'emoji', 'name': 'sunflower', 'unicode': '1f33b'}]}]}],
#   'reactions': [{'name': 'purple_heart',
#     'users': ['U05MSD5TYP5',
#      'U01M3018BTP',
#      'U065NUTL84A',
#      'U01L71AMFPG',
#      'U05AA7W7NR3',
#      'U05MSA7EBT5',
#      'U062B84FXJB'],
#     'count': 7}]},
#  {'user': 'U065NUTL84A',
#   'type': 'message',
#   'ts': '1717247812.689389',
#   'client_msg_id': '5c5b4411-4d05-4538-875f-09ec9de4e148',
#   'text': 'Buenos días :heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'JcPjV',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'heart', 'unicode': '2764-fe0f'}]}]}],
#   'reactions': [{'name': 'purple_heart',
#     'users': ['U05MSD5TYP5',
#      'U062B84FXJB',
#      'U01M3018BTP',
#      'U01L71AMFPG',
#      'U05AA7W7NR3',
#      'U05MSA7EBT5'],
#     'count': 6}]},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717247749.949479',
#   'client_msg_id': '82c8666a-cc8a-4004-a3f7-0e93acaaaa38',
#   'text': 'Buenos dìas',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'jHuxV',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos dìas'}]}]}],
#   'reactions': [{'name': 'heart',
#     'users': ['U065NUTL84A',
#      'U05MSD5TYP5',
#      'U062B84FXJB',
#      'U01M3018BTP',
#      'U01L71AMFPG',
#      'U05AA7W7NR3',
#      'U05MSA7EBT5'],
#     'count': 7}]},
#  {'user': 'U062B84FXJB',
#   'type': 'message',
#   'ts': '1717247691.479149',
#   'client_msg_id': '1e2cbd63-54b9-49a5-bb6e-708d572fe17d',
#   'text': 'Buuuenos días:sunny::blue_heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'iq9fY',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buuuenos días'},
#        {'type': 'emoji', 'name': 'sunny', 'unicode': '2600-fe0f'},
#        {'type': 'emoji', 'name': 'blue_heart', 'unicode': '1f499'}]}]}],
#   'reactions': [{'name': 'heart',
#     'users': ['U065NUTL84A',
#      'U05MSD5TYP5',
#      'U01M3018BTP',
#      'U01L71AMFPG',
#      'U05AA7W7NR3',
#      'U05MSA7EBT5'],
#     'count': 6}]},
#  {'user': 'U065NUTL84A',
#   'type': 'message',
#   'ts': '1717196452.099099',
#   'client_msg_id': '91b3c6e3-dd48-4aff-ab63-9393e7ea7433',
#   'text': 'Feliz tarde :heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Cd64D',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Feliz tarde '},
#        {'type': 'emoji', 'name': 'heart', 'unicode': '2764-fe0f'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717191563.589209',
#   'client_msg_id': 'f2968e2c-7ef2-4c7b-acf6-db9e5ceea4ff',
#   'text': '<@U01L71AMFPG> No pertenece 30505764',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'EkDWt',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' No pertenece 30505764'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717190081.647879',
#   'client_msg_id': 'cb485e64-c9ce-4431-a78e-595cab0e5991',
#   'text': 'Buenas tardes Cami, tenemos publicidad para redes sociales de C9 para las NE? <@U05QZNBJPSR>',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717190081.647879',
#   'reply_count': 2,
#   'reply_users_count': 2,
#   'latest_reply': '1717261803.501369',
#   'reply_users': ['U05QZNBJPSR', 'U05AA7W7NR3'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': '3KXMm',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Buenas tardes Cami, tenemos publicidad para redes sociales de C9 para las NE? '},
#        {'type': 'user', 'user_id': 'U05QZNBJPSR'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717189945.426989',
#   'client_msg_id': '707a1e03-a186-494d-b5d6-efad76e961fb',
#   'text': '<@U01L71AMFPG> No pertenece 39021434',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'kke8Z',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' No pertenece 39021434'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717189670.553989',
#   'client_msg_id': 'a0800e08-c789-4b84-a1dc-510b9894498a',
#   'text': '<@U01L71AMFPG> 40731434 tipificada anteriormente como No continúa',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'qNJr0',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' 40731434 tipificada anteriormente como No continúa'}]}]}]},
#  {'user': 'U065NUTL84A',
#   'type': 'message',
#   'ts': '1717189429.962959',
#   'client_msg_id': '04690f86-0f20-4a77-a944-0232e0a67c26',
#   'text': '<@U01L71AMFPG> NE no continua 37946993 del día de ayer',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'pE5Sy',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' NE no continua 37946993 del día de ayer'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717183288.988039',
#   'client_msg_id': '946a348e-ca8d-4c05-88c3-38dec69beb31',
#   'text': '<@U01L71AMFPG> No pertenece 1117517857',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'JrrlT',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' No pertenece 1117517857'}]}]}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717183265.241659',
#   'client_msg_id': 'e70d6838-101f-48b0-9ec3-37adabe974ff',
#   'text': '<@U01L71AMFPG> Ya se había contactado el día de ayer con contacto efectivo: <https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3Dd043a7ac-a221-8560-9efe-65dca73855b4|https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3Dd043a7ac-a221-8560-9efe-65dca73855b4>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'KhU88',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' Ya se había contactado el día de ayer con contacto efectivo: '},
#        {'type': 'link',
#         'url': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3Dd043a7ac-a221-8560-9efe-65dca73855b4',
#         'text': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3Dd043a7ac-a221-8560-9efe-65dca73855b4'}]}]}]},
#  {'user': 'U04229KLR6E',
#   'type': 'message',
#   'ts': '1717176037.582929',
#   'client_msg_id': 'd79393e6-9f6d-45fd-88dc-45cf96cc25d6',
#   'text': '<!channel> ya debe funcionar con normalidad el boton de presentación.',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717176037.582929',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1717176449.101159',
#   'reply_users': ['U065NUTL84A'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'eIGNY',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text',
#         'text': ' ya debe funcionar con normalidad el boton de presentación.'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U05MSD5TYP5', 'U065NUTL84A'],
#     'count': 2}]},
#  {'user': 'U062B84FXJB',
#   'type': 'message',
#   'ts': '1717175315.746699',
#   'client_msg_id': '00f7bb2b-710f-4782-9d58-967761edb19d',
#   'text': 'Almuerzo',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'jzVMp',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Almuerzo'}]}]}]},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717175036.915729',
#   'client_msg_id': '9dd4a9e0-ee9a-43bd-916c-c52a565177ec',
#   'text': '<@U01L71AMFPG> NE no pertence, <https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3D12753b19-52b8-f20d-c207-65dcab0c84a3|https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3D12753b19-52b8-f20d-c207-65dcab0c84a3>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '4ORCu',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' NE no pertence, '},
#        {'type': 'link',
#         'url': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3D12753b19-52b8-f20d-c207-65dcab0c84a3',
#         'text': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3D12753b19-52b8-f20d-c207-65dcab0c84a3'}]}]}]},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717173152.061239',
#   'edited': {'user': 'U05MSD5TYP5', 'ts': '1717173170.000000'},
#   'client_msg_id': 'ea625add-da33-4c86-aad8-86a0c0c0a995',
#   'text': 'el botón de CRM para enviar msj no está funcionado?',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717173152.061239',
#   'reply_count': 4,
#   'reply_users_count': 3,
#   'latest_reply': '1717175877.219999',
#   'reply_users': ['U03KUR8GFR8', 'U065NUTL84A', 'U04229KLR6E'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'LCdjS',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'el botón de CRM para enviar msj no está funcionado?'}]}]}]},
#  {'user': 'U05MSD5TYP5',
#   'type': 'message',
#   'ts': '1717171983.757709',
#   'client_msg_id': 'e623c6ce-7871-43f8-a01e-020c461c0589',
#   'text': '<@U01L71AMFPG> NE no pertenece <https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3Ddd0cd6d8-643b-c3c3-1e68-65dca717ee67|https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3Ddd0cd6d8-643b-c3c3-1e68-65dca717ee67>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Vp71R',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' NE no pertenece '},
#        {'type': 'link',
#         'url': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D1%26stamp%3D1692456308063720400%26return_module%3DLeads%26action%3DDetailView%26record%3Ddd0cd6d8-643b-c3c3-1e68-65dca717ee67',
#         'text': 'https://zafiro.likeu.co/index.php?action=ajaxui#ajaxUILoc=index.php%3Fmodule%3DLeads%26offset%3D[…]w%26record%3Ddd0cd6d8-643b-c3c3-1e68-65dca717ee67'}]}]}]},
#  {'user': 'U03KUR8GFR8',
#   'type': 'message',
#   'ts': '1717171893.438059',
#   'client_msg_id': 'ea5463fd-ad1b-4ed9-8bfc-d2beb3f46f3d',
#   'text': '<@U01L71AMFPG> Pao la base que esta gestionando cierre temprano esta muy negativa porque son NE que llevan más de 4 campañas consecutivas sin pasar pedido, la mayoria o corta la llamada o no continua, o ya tenia esa tipificación anteriormente',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NO8OL',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' Pao la base que esta gestionando cierre temprano esta muy negativa porque son NE que llevan más de 4 campañas consecutivas sin pasar pedido, la mayoria o corta la llamada o no continua, o ya tenia esa tipificación anteriormente'}]}]}],
#   'reactions': [{'name': 'point_up_2', 'users': ['U065NUTL84A'], 'count': 1},
#    {'name': 'point_up_2::skin-tone-2', 'users': ['U05AA7W7NR3'], 'count': 1}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717171523.333039',
#   'client_msg_id': '9ecb76b6-ef32-4309-9183-d2bc0c53b72f',
#   'text': '<@U01L71AMFPG> 1001171388 tipificada como No continúa',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'WBlkA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' 1001171388 tipificada como No continúa'}]}]}]},
#  {'user': 'U03KUR8GFR8',
#   'type': 'message',
#   'ts': '1717171088.169259',
#   'client_msg_id': '2eb69cde-e74e-4a81-9732-4ddc4e985a62',
#   'text': '<@U01L71AMFPG> ya la han llamado varias veces y esta como no continua 1024550991',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717171088.169259',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1717172458.255389',
#   'reply_users': ['U065NUTL84A'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'pCKKs',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text',
#         'text': ' ya la han llamado varias veces y esta como no continua 1024550991'}]}]}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717170010.990199',
#   'client_msg_id': 'b54a2220-fc38-4c5d-a180-9df6fb9e2d9e',
#   'text': '<@U01L71AMFPG> 39353749 No pertenece',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'IxPCl',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' 39353749 No pertenece'}]}]}]},
#  {'user': 'U05MSA7EBT5',
#   'type': 'message',
#   'ts': '1717168573.981219',
#   'client_msg_id': 'cfacb275-6902-41dc-8609-ebd6ab22c8e1',
#   'text': '<@U04229KLR6E>, otra vez pasó con esta NE <tel:+3183979414|+3183979414>. :face_with_head_bandage:',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717168573.981219',
# ...
#    'team': 'T01LAKECKEH',
#    'thread_ts': '1717086611.252249',
#    'reply_count': 2,
#    'reply_users_count': 2,
#    'latest_reply': '1717088067.343929',
#    'reply_users': ['U01L71AMFPG', 'U05R1HSKN80'],
#    'is_locked': False,
#    'subscribed': False,
#    'blocks': [{'type': 'rich_text',
#      'block_id': 'rv8KU',
#      'elements': [{'type': 'rich_text_section',
#        'elements': [{'type': 'text',
#          'text': 'Sería bueno poder sugerir, que la herramienta les muestre a la NE de contado enseguida, el valor total a pagar, estoy segura que eso evitaría muchos pedidos rechazados y a veces si no alcanzamos a notificarles se quedan sin su pedido, como le decía el otro día a Cami, una ne dijo que se iba a retirar porque se molestó muchísimo, por que el rechazo era por $333 pesos '},
#         {'type': 'emoji', 'name': 'melting_face', 'unicode': '1fae0'}]}]}]},
#   'type': 'message',
#   'ts': '1717087777.522399',
#   'client_msg_id': 'ed8a96e2-0044-4cf2-a5eb-28256d9e970d',
#   'text': 'POrfa de esos casos me pasas el valor del saldo, el valor que debia pagar segun el sistema y el numero de cedula de la NE para escalarlos para que les liberen el pedido.',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'oMq2u',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'POrfa de esos casos me pasas el valor del saldo, el valor que debia pagar segun el sistema y el numero de cedula de la NE para escalarlos para que les liberen el pedido.'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U065NUTL84A'],
#     'count': 1}]},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717086611.252249',
#   'edited': {'user': 'U05R1HSKN80', 'ts': '1717086679.000000'},
#   'client_msg_id': 'bf4af7a9-19a6-424e-aea3-15eca751578e',
#   'text': 'Sería bueno poder sugerir, que la herramienta les muestre a la NE de contado enseguida, el valor total a pagar, estoy segura que eso evitaría muchos pedidos rechazados y a veces si no alcanzamos a notificarles se quedan sin su pedido, como le decía el otro día a Cami, una ne dijo que se iba a retirar porque se molestó muchísimo, por que el rechazo era por $333 pesos :melting_face:',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717086611.252249',
#   'reply_count': 2,
#   'reply_users_count': 2,
#   'latest_reply': '1717088067.343929',
#   'reply_users': ['U01L71AMFPG', 'U05R1HSKN80'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'rv8KU',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Sería bueno poder sugerir, que la herramienta les muestre a la NE de contado enseguida, el valor total a pagar, estoy segura que eso evitaría muchos pedidos rechazados y a veces si no alcanzamos a notificarles se quedan sin su pedido, como le decía el otro día a Cami, una ne dijo que se iba a retirar porque se molestó muchísimo, por que el rechazo era por $333 pesos '},
#        {'type': 'emoji', 'name': 'melting_face', 'unicode': '1fae0'}]}]}],
#   'reactions': [{'name': 'point_up_2', 'users': ['U065NUTL84A'], 'count': 1}]},
#  {'text': '',
#   'files': [{'id': 'F075N85A2MC',
#     'created': 1717086511,
#     'timestamp': 1717086511,
#     'name': 'imagen.png',
#     'title': 'imagen.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U05R1HSKN80',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 25715,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F075N85A2MC/imagen.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F075N85A2MC/download/imagen.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075N85A2MC-3742464ccb/imagen_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075N85A2MC-3742464ccb/imagen_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075N85A2MC-3742464ccb/imagen_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 252,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075N85A2MC-3742464ccb/imagen_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 335,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075N85A2MC-3742464ccb/imagen_160.png',
#     'original_w': 558,
#     'original_h': 390,
#     'thumb_tiny': 'AwAhADDSLY7H8BSg5FIeo60tABRSY5z/AFoIzQAtIyhsZ7HNLRQAh/Ck59qdRQAgpc0UUAGaKKKAI6SlpKACiiigApaSloA//9k=',
#     'permalink': 'https://somoslikeu.slack.com/files/U05R1HSKN80/F075N85A2MC/imagen.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F075N85A2MC-9c2c9e35ea',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U05R1HSKN80',
#   'display_as_bot': False,
#   'type': 'message',
#   'ts': '1717086514.038259',
#   'client_msg_id': 'f7dc2b9e-7d52-4619-8a28-a55caac5e332'},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717086510.249829',
#   'client_msg_id': 'fb5243ed-8d2b-49ab-b001-761e15aec3d4',
#   'text': '<@U01L71AMFPG> <@U05QZNBJPSR> tengo varios casos de ne contado con pedidos rechazados por saldos mínimos, según lo que ellas me indican pagan el total que les dice el sistema, sin embargo; siempre les hace falta un monto mínimo y el sistema les rechaza el pedido, se enojan muchísimo porque son saldos muy pequeños que el sistema no les muestra cuando ellas van a pagar y cuando les notifico se molestan, porque muchas se movilizan hasta un punto de pago y solo a pagar 100, 200 o en este caso :point_down: 49 pesos :upside_down_face:',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1717086510.249829',
#   'reply_count': 4,
#   'reply_users_count': 2,
#   'latest_reply': '1717088457.558509',
#   'reply_users': ['U01L71AMFPG', 'U05R1HSKN80'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'vzA2N',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L71AMFPG'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'user', 'user_id': 'U05QZNBJPSR'},
#        {'type': 'text',
#         'text': ' tengo varios casos de ne contado con pedidos rechazados por saldos mínimos, según lo que ellas me indican pagan el total que les dice el sistema, sin embargo; siempre les hace falta un monto mínimo y el sistema les rechaza el pedido, se enojan muchísimo porque son saldos muy pequeños que el sistema no les muestra cuando ellas van a pagar y cuando les notifico se molestan, porque muchas se movilizan hasta un punto de pago y solo a pagar 100, 200 o en este caso '},
#        {'type': 'emoji', 'name': 'point_down', 'unicode': '1f447'},
#        {'type': 'text', 'text': ' 49 pesos '},
#        {'type': 'emoji', 'name': 'upside_down_face', 'unicode': '1f643'}]}]}]},
#  {'user': 'U065NUTL84A',
#   'type': 'message',
#   'ts': '1717081342.923029',
#   'client_msg_id': 'e43c107c-3118-43d0-887b-701167d3b2b4',
#   'text': 'Buenos días :heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'JcPjV',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'heart', 'unicode': '2764-fe0f'}]}]}]},
#  {'user': 'U01M3018BTP',
#   'type': 'message',
#   'ts': '1717078898.169049',
#   'client_msg_id': 'ccd6fc5c-d1b9-476c-b51c-cab6f284b986',
#   'text': 'Buenos dìas :rainbow:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'XDupj',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos dìas '},
#        {'type': 'emoji', 'name': 'rainbow', 'unicode': '1f308'}]}]}]},
#  {'text': '<!channel>, nos vemos a las 10:00 am en nuestro ciclo formativo :male-student::skin-tone-4:\n\nLink: <http://meet.google.com/pwc-hhdw-upa|meet.google.com/pwc-hhdw-upa>',
#   'files': [{'id': 'F075M5D3BSS',
#     'created': 1717076891,
#     'timestamp': 1717076891,
#     'name': 'Post de instagram capacitación online moderno gris.png',
#     'title': 'Post de instagram capacitación online moderno gris.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U05QZNBJPSR',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 260106,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F075M5D3BSS/post_de_instagram_capacitaci__n_online_moderno_gris.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F075M5D3BSS/download/post_de_instagram_capacitaci__n_online_moderno_gris.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 360,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 480,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 720,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 800,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_960.png',
#     'thumb_960_w': 960,
#     'thumb_960_h': 960,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075M5D3BSS-d55d2d6252/post_de_instagram_capacitaci__n_online_moderno_gris_1024.png',
#     'thumb_1024_w': 1024,
#     'thumb_1024_h': 1024,
#     'original_w': 1080,
#     'original_h': 1080,
#     'thumb_tiny': '',
#     'permalink': 'https://somoslikeu.slack.com/files/U05QZNBJPSR/F075M5D3BSS/post_de_instagram_capacitaci__n_online_moderno_gris.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F075M5D3BSS-0cfafa2260',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U05QZNBJPSR',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'hkGS9',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text',
#         'text': ', nos vemos a las 10:00 am en nuestro ciclo formativo '},
#        {'type': 'emoji',
#         'name': 'male-student',
#         'unicode': '1f468-1f3fd-200d-1f393',
#         'skin_tone': 4},
#        {'type': 'text', 'text': '\n\nLink: '},
#        {'type': 'link',
#         'url': 'http://meet.google.com/pwc-hhdw-upa',
#         'text': 'meet.google.com/pwc-hhdw-upa'}]}]}],
#   'type': 'message',
#   'ts': '1717077036.852879',
#   'client_msg_id': '3599d705-effb-4bc0-9b70-6e3a1510b558',
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U05R1HSKN80',
#      'U05AA7W7NR3',
#      'U05MSD5TYP5',
#      'U03KUR8GFR8',
#      'U065NUTL84A',
#      'U01M3018BTP',
#      'U062B84FXJB'],
#     'count': 7}]},
#  {'user': 'U05AA7W7NR3',
#   'type': 'message',
#   'ts': '1717075103.860219',
#   'client_msg_id': '764fc1e9-e37e-4e2e-be8e-f95768af28e6',
#   'text': 'Buenos días :sunny:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'p7YS1',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'sunny', 'unicode': '2600-fe0f'}]}]}]},
#  {'user': 'U05R1HSKN80',
#   'type': 'message',
#   'ts': '1717074553.660519',
#   'client_msg_id': 'ff8a31e3-66ad-4f02-bcc6-11e70ffa6b19',
#   'text': 'Buenos días :sun_with_face:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Zb1H/',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenos días '},
#        {'type': 'emoji', 'name': 'sun_with_face', 'unicode': '1f31e'}]}]}]},
#  {'user': 'U05QZNBJPSR',
#   'type': 'message',
#   'ts': '1717074538.412039',
#   'client_msg_id': 'b8785400-b841-49c0-bd21-66ea65db09ed',
#   'text': '<!channel> ¡Buenos días, equipo! ¡Feliz jueves! :muscle::sparkles:\nHoy es un día perfecto para alcanzar nuestros objetivos y superar nuestras metas. No se ustedes, pero yo ayer en el espacio con Novaventa entendí muchas más cosas del negocio, para seguir sacándolo adelante. Sigamos impulsando nuestras ventas, mejorando nuestra gestión comercial con entusiasmo y determinación. Recuerden que cada llamada y cada esfuerzo cuentan. _¡Vamos a impactar verdaderamente este jueves a nuestras Novaempresarias!_\n¡Vamos por todo! :rocket::top:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '8dVE6',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text', 'text': ' ¡Buenos días, equipo! ¡Feliz jueves! '},
#        {'type': 'emoji', 'name': 'muscle', 'unicode': '1f4aa'},
#        {'type': 'emoji', 'name': 'sparkles', 'unicode': '2728'},
#        {'type': 'text',
#         'text': '\nHoy es un día perfecto para alcanzar nuestros objetivos y superar nuestras metas. No se ustedes, pero yo ayer en el espacio con Novaventa entendí muchas más cosas del negocio, para seguir sacándolo adelante. Sigamos impulsando nuestras ventas, mejorando nuestra gestión comercial con entusiasmo y determinación. Recuerden que cada llamada y cada esfuerzo cuentan. '},
#        {'type': 'text',
#         'text': '¡Vamos a impactar verdaderamente este jueves a nuestras Novaempresarias!',
#         'style': {'italic': True}},
#        {'type': 'text', 'text': '\n¡Vamos por todo! '},
#        {'type': 'emoji', 'name': 'rocket', 'unicode': '1f680'},
#        {'type': 'emoji', 'name': 'top', 'unicode': '1f51d'}]}]}],
#   'reactions': [{'name': 'raised_hands',
#     'users': ['U062B84FXJB', 'U05MSD5TYP5', 'U03KUR8GFR8'],
#     'count': 3},
#    {'name': 'raised_hands::skin-tone-2', 'users': ['U05AA7W7NR3'], 'count': 1},
#    {'name': 'sunflower', 'users': ['U01M3018BTP'], 'count': 1}]},
#  {'user': 'U062B84FXJB',
#   'type': 'message',
#   'ts': '1717074159.266389',
#   'client_msg_id': '1eaff7ac-7c51-4f41-9d42-6a8fcb9221c1',
#   'text': 'Bueenos días :blue_heart:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'bZXhq',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Bueenos días '},
#        {'type': 'emoji', 'name': 'blue_heart', 'unicode': '1f499'}]}]}]}]
