# %% [markdown]
# # Configuración inicial del extractor de mensajes
# Primero se hacen pruebas en el notebook y después se pasa la información relevante a un archivo .py que va a ser ejecutado cada cierto tiempo para ir actualizando con mensajes nuevos

# %%
import requests
from datetime import datetime
import json
import os

# Configurar el token y el ID del canal de Slack
token = "some_token"
channel_id = "some_channel"  # Reemplaza con el ID del canal correcto

# Configurar los encabezados de la solicitud
headers = {
    "Authorization": f"Bearer {token}"
}

# DEFINICION DE FUNCIONES
# Función para almacenar y leer el último timestamp
def get_last_timestamp(file_path="last_timestamp.json"):
    try:
        with open(file_path, 'r', encoding = 'utf-8') as f:
            data = json.load(f)
            return data.get('last_timestamp', None)
    except FileNotFoundError:
        return None

def save_last_timestamp(timestamp, file_path="last_timestamp.json"):
    with open(file_path, 'w', encoding = 'utf-8') as f:
        json.dump({'last_timestamp': timestamp}, f)

# Función para extraer mensajes del canal de Slack
def fetch_messages(oldest_timestamp=None, oldest = None, latest = None):
    url = f"https://slack.com/api/conversations.history?channel={channel_id}"

    if oldest_timestamp:
        url += f"&oldest={oldest_timestamp}"
    if oldest:
        oldest_ts = datetime.strptime(oldest, "%Y-%m-%d %H:%M:%S").timestamp()
        url += f"&oldest={oldest_ts}"
    if latest:
        latest_ts = datetime.strptime(latest, "%Y-%m-%d %H:%M:%S").timestamp()
        url += f"&latest={latest_ts}"

    response = requests.get(url, headers=headers)

    # Verificar si la solicitud fue exitosa
    if response.status_code != 200:
        print("Error al obtener mensajes:", response.status_code, response.text)
        return []

    data = response.json()

    # Verificar si la respuesta contiene 'messages'
    if not data.get('ok'):
        print("Error:", data.get('error'))
        return []

    return data["messages"]

# -----------------------------------------------------
# NUEVO
# Función para obtener respuestas de un hilo
def fetch_thread_messages(thread_ts):
    url = f"https://slack.com/api/conversations.replies?channel={channel_id}&ts={thread_ts}"
    response = requests.get(url, headers=headers)

    # Verificar si la solicitud fue exitosa
    if response.status_code != 200:
        print("Error al obtener mensajes del hilo:", response.status_code, response.text)
        return []

    data = response.json()

    # Verificar si la respuesta contiene 'messages'
    if not data.get('ok'):
        print("Error:", data.get('error'))
        return []

    # Ignorar el primer mensaje ya que es el mensaje principal
    return data["messages"] # return data["messages"][1:]

# -----------------------------------------------------


# Función para obtener la información del usuario
def get_user_info(user_id):
    url = f"https://slack.com/api/users.info?user={user_id}"
    response = requests.get(url, headers=headers)

    # Verificar si la solicitud fue exitosa
    if response.status_code != 200:
        print(f"Error al obtener información del usuario {user_id}:", response.status_code, response.text)
        return None

    data = response.json()

    # Verificar si la respuesta contiene 'user'
    if not data.get('ok'):
        print(f"Error al obtener información del usuario {user_id}:", data.get('error'))
        return None

    return data["user"]

# -------------------------------------------------------------------
# NUEVO
# Nuevas funciones para identificar el tipo de mensaje
# Función para verificar si un mensaje es una pregunta
def is_question(message_text):
    return message_text.endswith('?') or any(word in message_text.lower() for word in ['qué', 'cuál', 'dónde', 'cuándo', 'por qué', 'cómo'])

# Función para verificar si un mensaje contiene una imagen
def contains_image(message):
    if 'files' in message:
        file = message.get('files')

    return 'files' in message or 'attachments' in message

# -------------------------------------------------------------------

# Función para procesar y almacenar mensajes en un archivo histórico
def process_and_store_messages(messages, history_file="message_history.json"):
    user_cache = {}
    historical_data = []

    # Leer el archivo histórico si existe
    if os.path.exists(history_file):
        with open(history_file, 'r', encoding = 'utf-8') as f:
            historical_data = json.load(f)

    # Procesar y almacenar los mensajes
    for message in messages:
        user_id = message.get('user')
        client_msg_id = message.get('client_msg_id')
        text = message.get('text')
        timestamp = message.get('ts')

        # Convertir el timestamp a un formato legible
        dt_object = datetime.fromtimestamp(float(timestamp))
        formatted_time = dt_object.strftime('%Y-%m-%d %H:%M:%S')

        # Obtener información del usuario, utilizando el cache si ya se ha consultado
        if user_id not in user_cache:
            user_info = get_user_info(user_id)
            if user_info:
                user_cache[user_id] = user_info.get('real_name', 'Unknown User')
            else:
                user_cache[user_id] = 'Unknown User'

        user_name = user_cache[user_id]


        # Identificar tipo de mensaje
        message_type = "other"
        if is_question(text):
            message_type = "question"
        elif 'thread_ts' in message:
            message_type = "thread_start"
        elif contains_image(message):
            message_type = "image"
            continue  # Ignorar mensajes con imágenes

        # Agregar el mensaje al archivo histórico
        historical_data.append({
            'user_id': user_id,
            'client_msg_id': client_msg_id,
            'user_name': user_name,
            'text': text,
            'timestamp': formatted_time,
            'type': message_type,
            'thread_start_msg_id': None
        })


        # Si el mensaje tiene un hilo, obtener los mensajes del hilo
        if 'thread_ts' in message:
            thread_messages = fetch_thread_messages(message['thread_ts'])
            thread_start_msg_id = thread_messages[0].get('client_msg_id')
            for thread_message in thread_messages[1:]:
                user_id = thread_message.get('user')
                client_msg_id = thread_message.get('client_msg_id')
                text = thread_message.get('text')
                timestamp = thread_message.get('ts')

                # Convertir el timestamp a un formato legible
                dt_object = datetime.fromtimestamp(float(timestamp))
                formatted_time = dt_object.strftime('%Y-%m-%d %H:%M:%S')

                # Obtener información del usuario, utilizando el cache si ya se ha consultado
                if user_id not in user_cache:
                    user_info = get_user_info(user_id)
                    if user_info:
                        user_cache[user_id] = user_info.get('real_name', 'Unknown User')
                    else:
                        user_cache[user_id] = 'Unknown User'

                user_name = user_cache[user_id]

                # Identificar tipo de mensaje en el hilo
                message_type = "other"
                if is_question(text):
                    message_type = "question"
                elif contains_image(thread_message):
                    message_type = "image"
                    continue  # Ignorar mensajes con imágenes
                else:
                    message_type = "response"

                # Agregar el mensaje del hilo al archivo histórico
                historical_data.append({
                    'user_id': user_id,
                    'client_msg_id': client_msg_id,
                    'user_name': user_name,
                    'text': text,
                    'timestamp': formatted_time,
                    'type': message_type,
                    'thread_start_msg_id': thread_start_msg_id
                })

    # Guardar el archivo histórico actualizado
    with open(history_file, 'w', encoding = 'utf-8') as f:
        json.dump(historical_data, f, indent=4)

# Eliminacion de mensajes duplicados
def remove_duplicates(history_file="message_history.json"):
    try:
        # Leer el archivo histórico
        with open(history_file, 'r', encoding = 'utf-8') as f:
            historical_data = json.load(f)
    except FileNotFoundError:
        print(f"Archivo {history_file} no encontrado.")
        return

    # Utilizar un conjunto para rastrear los mensajes únicos
    unique_messages = []
    seen_messages = set()

    for message in historical_data:
        message_tuple = (message['user_id'], message['client_msg_id'], message['user_name'], message['text'],
                         message['timestamp'], message['type'], message['thread_start_msg_id'])
        if message_tuple not in seen_messages:
            seen_messages.add(message_tuple)
            unique_messages.append(message)

    # Guardar el archivo histórico actualizado sin duplicados
    with open(history_file, 'w') as f:
        json.dump(unique_messages, f, indent=4)

    print(f"Se eliminaron duplicados. {len(historical_data) - len(unique_messages)} mensajes eliminados.")

# %%
# EXTRACCION DEL MENSAJE
# Extraer y procesar los mensajes
last_timestamp = get_last_timestamp()  # Obtener el último timestamp procesado
messages = fetch_messages(oldest_timestamp=last_timestamp)  # Extraer mensajes desde el último timestamp
if messages:
    process_and_store_messages(messages)  # Procesar y almacenar los mensajes
    # Guardar el timestamp del último mensaje procesado
    save_last_timestamp(messages[0]['ts'])

# Eliminar duplicados del archivo histórico
remove_duplicates()
# Out:
# Se eliminaron duplicados. 0 mensajes eliminados.

# %%
szs = fetch_messages()

# %%
szs
# Out:
# [{'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1717199633.693099',
#   'client_msg_id': 'd9f9a034-be61-487d-b6e6-a58802828c34',
#   'text': 'Btw, acabo de solucionar el problema de conexión que me surgió ayer xd',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'WVeWJ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Btw, acabo de solucionar el problema de conexión que me surgió ayer xd'}]}]}],
#   'reactions': [{'name': '+1',
#     'users': ['U06SPFKSFU2', 'U06S28H3CFR'],
#     'count': 2}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1717199593.268589',
#   'client_msg_id': '862280d6-6d87-41be-9093-87aa6ff8a0e6',
#   'text': 'Prueba luego de reinstalación',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '9ucRQ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Prueba luego de reinstalación'}]}]}]},
#  {'subtype': 'channel_join',
#   'user': 'U074KB2A2JZ',
#   'text': '<@U074KB2A2JZ> se unió al canal',
#   'inviter': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1717199075.226229'},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1717105082.733529',
#   'client_msg_id': '99856308-5ab9-4e7b-b46f-a840be3d596e',
#   'text': 'Yo también estoy esperando que me den ingreso <@U06S28H3CFR>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'wSd0A',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Yo también estoy esperando que me den ingreso '},
#        {'type': 'user', 'user_id': 'U06S28H3CFR'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U06S28H3CFR'],
#     'count': 1}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1717105056.056679',
#   'client_msg_id': '7bf73315-e024-485f-b6b8-bfaf18c2f0d4',
#   'text': '<@U01L6UJGRSS> <@U06SGR43U1G> <@U06SPFKSFU2> <@U06T5JSMBQQ>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Nq00+',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L6UJGRSS'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'user', 'user_id': 'U06SGR43U1G'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'user', 'user_id': 'U06SPFKSFU2'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'user', 'user_id': 'U06T5JSMBQQ'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1717105029.310999',
#   'client_msg_id': '1977a49a-9b10-45f6-ad75-ce77bac92fcf',
#   'text': 'Equipo que mas, estoy intentando entrar a la reunion pero aun no me acpetan, no se si aun no inicia o es un error de mi conexion, si ya inicio me dicen porfa jajajaja',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '/jZvN',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Equipo que mas, estoy intentando entrar a la reunion pero aun no me acpetan, no se si aun no inicia o es un error de mi conexion, si ya inicio me dicen porfa jajajaja'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1717097703.195169',
#   'client_msg_id': '35cff4fd-af86-4505-b4e2-0455ef63cd7e',
#   'text': 'llego normal',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'C2bcO',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'llego normal'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1717097296.198399',
#   'client_msg_id': '31faafeb-dcf6-47df-902e-25693506ca35',
#   'text': 'Mensaje de prueba',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'IRjmW',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Mensaje de prueba'}]}]}]},
#  {'text': '',
#   'files': [{'id': 'F075Y9P51S8',
#     'created': 1717096207,
#     'timestamp': 1717096207,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U01L6UJGRSS',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 6981,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F075Y9P51S8/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F075Y9P51S8/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075Y9P51S8-00db63e65a/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075Y9P51S8-00db63e65a/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075Y9P51S8-00db63e65a/image_360.png',
#     'thumb_360_w': 351,
#     'thumb_360_h': 104,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F075Y9P51S8-00db63e65a/image_160.png',
#     'original_w': 351,
#     'original_h': 104,
#     'thumb_tiny': 'AwAOADCZWU5Ls+cnpmmknJw0mM0jZViMDrSZPp+tdFjIXJ/vPQS3ZnpM+w/M0Z9v1piDL+rUbmH8TfnRn2H50h5NAH//2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U01L6UJGRSS/F075Y9P51S8/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F075Y9P51S8-65eaf15238',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U01L6UJGRSS',
#   'display_as_bot': False,
#   'type': 'message',
#   'ts': '1717096208.518459',
#   'client_msg_id': '4f6503d0-c003-49d0-90b9-13fd93fa70e6',
#   'reactions': [{'name': 'hushed', 'users': ['U06S28H3CFR'], 'count': 1}]},
#  {'text': '',
#   'files': [{'id': 'F074ZCQQGUC',
#     'created': 1716502101,
#     'timestamp': 1716502101,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U01L6UJGRSS',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 355746,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F074ZCQQGUC/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F074ZCQQGUC/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 203,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 271,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 407,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 452,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_960.png',
#     'thumb_960_w': 960,
#     'thumb_960_h': 542,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074ZCQQGUC-ee812a640c/image_1024.png',
#     'thumb_1024_w': 1024,
#     'thumb_1024_h': 578,
#     'original_w': 1360,
#     'original_h': 768,
#     'thumb_tiny': 'AwAbADCuixlTuDZz2xVq0iiZm+QnA/ixVaJVZSWYD65q3ZKqs+2QHpWjEiz9nh/55r+VH2eD/nkv5VKOnY0tRcZB9ltz/wAsk/Kg2kGP9Uv5VPSN90/Si4GGmQCKuaeCXk57CpbW3iaBGZASRyar3hNs48k7M5zim5XFY0wPelrHW5nJH7xqZJdzgJiVuRUjNukYfKfpWF9suP8Anq1OF3cbT+9agD//2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U01L6UJGRSS/F074ZCQQGUC/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F074ZCQQGUC-dd56578222',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U01L6UJGRSS',
#   'display_as_bot': False,
#   'type': 'message',
#   'ts': '1716502106.109449',
#   'client_msg_id': '4da70e72-94df-49df-a168-bfd4a8ad1fcb'},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1716501601.610739',
#   'client_msg_id': '74c56aaa-915a-4762-9543-f5e972d3eee1',
#   'text': 'Pruebas 3',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'jIFV1',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Pruebas 3'}]}]}]},
#  {'subtype': 'thread_broadcast',
#   'user': 'U01L6UJGRSS',
#   'thread_ts': '1716416417.206739',
#   'root': {'user': 'U06S28H3CFR',
#    'type': 'message',
#    'ts': '1716416417.206739',
#    'client_msg_id': '7cbf2c75-da2c-42cc-af96-6e8fff700c32',
#    'text': 'Hola bot',
#    'team': 'T01LAKECKEH',
#    'thread_ts': '1716416417.206739',
#    'reply_count': 2,
#    'reply_users_count': 1,
#    'latest_reply': '1716501539.752429',
#    'reply_users': ['U01L6UJGRSS'],
#    'is_locked': False,
#    'subscribed': False,
#    'blocks': [{'type': 'rich_text',
#      'block_id': 'yo5iB',
#      'elements': [{'type': 'rich_text_section',
#        'elements': [{'type': 'text', 'text': 'Hola bot'}]}]}]},
#   'type': 'message',
#   'ts': '1716501539.752429',
#   'client_msg_id': '4400c1e7-864b-4297-99ff-7d6c39941d20',
#   'text': 'Prueba 2',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '0FZpi',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Prueba 2'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1716499786.321849',
#   'client_msg_id': '0e8299ef-f521-43d8-be7a-6f876ad7cb47',
#   'text': 'Equipo me dan 10 min por favor',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'dxxCx',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Equipo me dan 10 min por favor'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U06SGR43U1G', 'U06T5JSMBQQ', 'U06S28H3CFR'],
#     'count': 3}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1716416417.206739',
#   'client_msg_id': '7cbf2c75-da2c-42cc-af96-6e8fff700c32',
#   'text': 'Hola bot',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1716416417.206739',
#   'reply_count': 2,
#   'reply_users_count': 1,
#   'latest_reply': '1716501539.752429',
#   'reply_users': ['U01L6UJGRSS'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'yo5iB',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hola bot'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1716414112.079719',
#   'client_msg_id': 'eadb3151-5c60-4327-93c0-34f345b8c9f1',
#   'text': 'Luego lo elimino, de momento es solo para hacer pruebas',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'BgbH1',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Luego lo elimino, de momento es solo para hacer pruebas'}]}]}],
#   'reactions': [{'name': '+1',
#     'users': ['U06SPFKSFU2', 'U06S28H3CFR'],
#     'count': 2},
#    {'name': '+1::skin-tone-2', 'users': ['U01L6UJGRSS'], 'count': 1}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1716414095.024619',
#   'client_msg_id': 'f14f25d5-6a36-4ffe-9548-af8849c1caab',
#   'text': 'Trate de hacerlo en mi chat personal o creando un nuevo canal de pruebas pero no me estaba dejando',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'LeldM',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Trate de hacerlo en mi chat personal o creando un nuevo canal de pruebas pero no me estaba dejando'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1716414068.867769',
#   'client_msg_id': '45f40160-c309-46fe-aae2-e26e8538b6e3',
#   'text': 'Muchachos acabo de agregar un bot al canal para probar la extracción de mensajes',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'yoP3E',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Muchachos acabo de agregar un bot al canal para probar la extracción de mensajes'}]}]}]},
#  {'subtype': 'channel_join',
#   'user': 'U074KB2A2JZ',
#   'text': '<@U074KB2A2JZ> se unió al canal',
#   'inviter': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1716414027.515149'},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715960078.049839',
#   'client_msg_id': 'b0c3a429-a581-4060-adca-f644b678bc84',
#   'text': 'Que más leo, a mi los lunes no me es posible a esa hora porque trabajo de manera presencial en la tarde, los lunes la verdad en general me queda difícil',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'QwKKa',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Que más leo, a mi los lunes no me es posible a esa hora porque trabajo de manera presencial en la tarde, los lunes la verdad en general me queda difícil'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715959986.429669',
#   'client_msg_id': '01eeaf62-c564-4390-babf-fd6408952358',
#   'text': 'Hola, yo personalmente me puedo seguir ajustando al horario propuesto',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'q6nrh',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hola, yo personalmente me puedo seguir ajustando al horario propuesto'}]}]}]},
#  {'user': 'U06SPFKSFU2',
#   'type': 'message',
#   'ts': '1715955135.084069',
#   'client_msg_id': 'c602ba9b-d28c-4b56-8eaa-35e6dcaf86ce',
#   'text': 'Buenos días. Me disculpo por no poder asistir ayer, tuve un inconveniente.\n\nSobre las disponibilidades, si no les molesta que ingrese a las reuniones mientras me estoy desplazando, podría seguir ingresando a la misma hora, con riesgos de que se extiendan otras reuniones.\n\nNo se si sea factible mover la hora',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'y302M',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Buenos días. Me disculpo por no poder asistir ayer, tuve un inconveniente.\n\nSobre las disponibilidades, si no les molesta que ingrese a las reuniones mientras me estoy desplazando, podría seguir ingresando a la misma hora, con riesgos de que se extiendan otras reuniones.\n\nNo se si sea factible mover la hora'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715954001.776769',
#   'client_msg_id': '733ec8da-4bd5-4b61-b987-fca337674a46',
#   'text': 'como están sus disponibilidades ?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'YEAkL',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'como están sus disponibilidades ?'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715953992.793389',
#   'client_msg_id': 'a8e70403-fc89-4bc3-8298-e077c39cee4a',
#   'text': 'que opinan Lunes y Miercoles , a la misma hora ?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '/uZ/C',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'que opinan Lunes y Miercoles , a la misma hora ?'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715953966.675369',
#   'client_msg_id': '15cf0c8d-92c6-4843-bc6d-5810c91e2d82',
#   'text': '<!channel>, buenos dias , ayer no revisamos el tema de la sincro de los Jueves , la idea de los martes y jueves me gustaba pq damos oportunidad a tener avances',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'W0l4g',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text',
#         'text': ', buenos dias , ayer no revisamos el tema de la sincro de los Jueves , la idea de los martes y jueves me gustaba pq damos oportunidad a tener avances'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715901750.532939',
#   'client_msg_id': '97f4c764-6ce3-40fd-9933-fea189d52773',
#   'text': 'Muchas gracias juanjo, todo correcto en la pestana de me',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'sCx/E',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Muchas gracias juanjo, todo correcto en la pestana de me'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715900755.270099',
#   'client_msg_id': 'af5244a6-1457-4ec8-8f64-a38c3d2f70b6',
#   'text': 'Esa si debería estar normal, la otra ni idea',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'eER1e',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Esa si debería estar normal, la otra ni idea'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715900744.464909',
#   'client_msg_id': 'fd2d16c6-709e-454f-b63f-1e3b61354a1c',
#   'text': 'Cambia la pestaña "All" por la pestaña "Me"',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'ynSUT',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Cambia la pestaña "All" por la pestaña "Me"'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715900712.096299',
#   'client_msg_id': '6b45496e-40f2-4cdb-8894-dfa423d48beb',
#   'text': 'No pero sabes que, ya pille el lio',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'z4ijX',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'No pero sabes que, ya pille el lio'}]}]}]},
#  {'text': 'Se enloquecio Hubstaff X2',
#   'files': [{'id': 'F073NN53ESJ',
#     'created': 1715900576,
#     'timestamp': 1715900576,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U06SGR43U1G',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 82064,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F073NN53ESJ/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F073NN53ESJ/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 167,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 223,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 334,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 371,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_960.png',
#     'thumb_960_w': 960,
#     'thumb_960_h': 446,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NN53ESJ-4304bcae41/image_1024.png',
#     'thumb_1024_w': 1024,
#     'thumb_1024_h': 475,
#     'original_w': 2160,
#     'original_h': 1003,
#     'thumb_tiny': 'AwAWADDS49qWiigAooooAKjfcCCCeo4AqSkJxj3NNCYZpaaOv406kMKKKKAEzRwcfWjvQP60xH//2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U06SGR43U1G/F073NN53ESJ/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F073NN53ESJ-11591179f9',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U06SGR43U1G',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'YLZmB',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Se enloquecio Hubstaff X2'}]}]}],
#   'type': 'message',
#   'ts': '1715900586.683569',
#   'client_msg_id': '20fc0b8c-6ef3-4de9-bdd7-575b11f7fb80'},
#  {'text': 'Gente el hubstaff esta raro o es solo el mio ? <!channel>\nMe aparecen menos horas que las que tenia y tambien me aparece como si las hubiera hecho todas hoy',
#   'files': [{'id': 'F073XQN44TE',
#     'created': 1715900281,
#     'timestamp': 1715900281,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U06S28H3CFR',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 58794,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F073XQN44TE/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F073XQN44TE/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 171,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 229,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 343,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 381,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_960.png',
#     'thumb_960_w': 960,
#     'thumb_960_h': 457,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073XQN44TE-e30aa57ddf/image_1024.png',
#     'thumb_1024_w': 1024,
#     'thumb_1024_h': 488,
#     'original_w': 1621,
#     'original_h': 772,
#     'thumb_tiny': 'AwAWADDS4z2peO1FFABRRQaACo3DBgQWOT09KepyAfWlp7C3CjmiikMOaOaKKAEAwAPSloooA//Z',
#     'permalink': 'https://somoslikeu.slack.com/files/U06S28H3CFR/F073XQN44TE/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F073XQN44TE-c6122f88ef',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U06S28H3CFR',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': '89Zpl',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Gente el hubstaff esta raro o es solo el mio ? '},
#        {'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text',
#         'text': '\nMe aparecen menos horas que las que tenia y tambien me aparece como si las hubiera hecho todas hoy'}]}]}],
#   'type': 'message',
#   'ts': '1715900436.464799',
#   'client_msg_id': '20ff9c50-8c1b-4249-a51a-fc694070ae87'},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715899697.059759',
#   'client_msg_id': 'ac2f0b90-6174-43c5-9af2-6f9ce52691b7',
#   'text': 'gracias',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'GkxYq',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'gracias'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715899695.637999',
#   'client_msg_id': '44bd7fd9-3fdf-4f3f-aa6e-9414d2c28cf3',
#   'text': 'de una',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'K6qUa',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'de una'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715899664.023319',
#   'client_msg_id': '53e79a5c-c0b3-4b2f-825d-73ce3d4c3609',
#   'text': 'Ya mismo te lo mando',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'yxYRL',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Ya mismo te lo mando'}]}]}]},
#  {'subtype': 'thread_broadcast',
#   'user': 'U01L6UJGRSS',
#   'thread_ts': '1715899320.647929',
#   'root': {'user': 'U01L6UJGRSS',
#    'type': 'message',
#    'ts': '1715899320.647929',
#    'client_msg_id': 'da6e95bf-88b1-4e95-a248-349a8a9fb43b',
#    'text': '3148253972',
#    'team': 'T01LAKECKEH',
#    'thread_ts': '1715899320.647929',
#    'reply_count': 1,
#    'reply_users_count': 1,
#    'latest_reply': '1715899650.444769',
#    'reply_users': ['U01L6UJGRSS'],
#    'is_locked': False,
#    'subscribed': False,
#    'blocks': [{'type': 'rich_text',
#      'block_id': 'fFS6G',
#      'elements': [{'type': 'rich_text_section',
#        'elements': [{'type': 'text', 'text': '3148253972'}]}]}]},
#   'type': 'message',
#   'ts': '1715899650.444769',
#   'client_msg_id': 'f871feed-3346-4e02-8232-d89301ac8619',
#   'text': '<@U06S28H3CFR>,para el video',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'D2tfI',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U06S28H3CFR'},
#        {'type': 'text', 'text': ',para el video'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U06S28H3CFR'],
#     'count': 1}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715899320.647929',
#   'client_msg_id': 'da6e95bf-88b1-4e95-a248-349a8a9fb43b',
#   'text': '3148253972',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1715899320.647929',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1715899650.444769',
#   'reply_users': ['U01L6UJGRSS'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'fFS6G',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': '3148253972'}]}]}]},
#  {'text': '<https://docs.google.com/spreadsheets/d/1POGxrQ9Pdhc4tT1SCfjOB2eT5NSiigtc/edit#gid=894115030>',
#   'files': [{'id': 'F073NKX1ZLN',
#     'created': 1715899125,
#     'timestamp': 1715899125,
#     'name': 'Guia Digital 2023.xlsx',
#     'title': 'Guia Digital 2024.xlsx',
#     'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#     'filetype': 'xlsx',
#     'pretty_type': 'Hoja de cálculo de Excel',
#     'user': 'U01L6UJGRSS',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 242157,
#     'mode': 'external',
#     'is_external': True,
#     'external_type': 'gdrive',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://docs.google.com/spreadsheets/d/1POGxrQ9Pdhc4tT1SCfjOB2eT5NSiigtc/edit#gid=894115030',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_360.png',
#     'thumb_360_w': 254,
#     'thumb_360_h': 360,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_480.png',
#     'thumb_480_w': 339,
#     'thumb_480_h': 480,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_720.png',
#     'thumb_720_w': 509,
#     'thumb_720_h': 720,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 1132,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_960.png',
#     'thumb_960_w': 678,
#     'thumb_960_h': 960,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073NKX1ZLN-8ee3f29cbe/guia_digital_2023_1024.png',
#     'thumb_1024_w': 724,
#     'thumb_1024_h': 1024,
#     'original_w': 1024,
#     'original_h': 1449,
#     'thumb_tiny': 'AwAwACG/I0gbCDI+lN3zf3R+VExUP8xI47Zpm+IDlj+ZpgP3yjqBj6f/AF6crsSM/wAqjDxNwrZP1NSKMEc96TAkooooAjc4bpnimkgj7v6ClkYB+SOlNYqR95PypdQHKBkfJ+OBUhHT61XbbtOCmfYc02E/vF5pgW6KKKAK87OJBtdQMd6j8yX/AJ6R1bKgnJo2CgCnI8pjPzo3sKdCMSirJQEYNIsSKcgcj3p3AfRRRSA//9k=',
#     'permalink': 'https://somoslikeu.slack.com/files/U01L6UJGRSS/F073NKX1ZLN/guia_digital_2023.xlsx',
#     'is_starred': False,
#     'external_id': '1POGxrQ9Pdhc4tT1SCfjOB2eT5NSiigtc',
#     'external_url': 'https://docs.google.com/spreadsheets/d/1POGxrQ9Pdhc4tT1SCfjOB2eT5NSiigtc/edit#gid=894115030',
#     'has_rich_preview': True,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U01L6UJGRSS',
#   'display_as_bot': False,
#   'x_files': ['F073NKX1ZLN'],
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Js6ua',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'link',
#         'url': 'https://docs.google.com/spreadsheets/d/1POGxrQ9Pdhc4tT1SCfjOB2eT5NSiigtc/edit#gid=894115030'}]}]}],
#   'type': 'message',
#   'ts': '1715899122.462869',
#   'client_msg_id': 'b0f4388c-ffa2-49fe-83a3-83d3ed99a12e'},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715897807.209699',
#   'client_msg_id': 'be018843-330a-4676-971d-5c2f5f63e790',
#   'text': 'Debemos considerar algun estandar de nombrado de documentos? ?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'w6zsJ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Debemos considerar algun estandar de nombrado de documentos? ?'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715881738.360449',
#   'client_msg_id': '59ff457a-2089-4858-9e63-cee38b0df33e',
#   'text': 'Hola hola buenos días, yo estaría disponible en el mismo horario miércoles o viernes',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '93B0O',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hola hola buenos días, yo estaría disponible en el mismo horario miércoles o viernes'}]}]}]},
#  {'text': 'Buenos días team, vengo a comentarles un inconveniente que tengo. En la otra empresa donde laboro me ocuparon los jueves de 4 a 6, este tiempo lo van hacer cada dos semanas. Quería comentarles si tal vez podamos mover ese daily a otro día de la semana? cualquier día de 4 a 5 excepto los jueves yo no tengo obligaciones, quedo pendiente a sus comentarios y propuestas. <!channel>',
#   'files': [{'id': 'F074G847FAL',
#     'created': 1715878102,
#     'timestamp': 1715878102,
#     'name': 'Captura de pantalla 2024-05-16 a la(s) 11.39.57\u202fa.\xa0m..png',
#     'title': 'Captura de pantalla 2024-05-16 a la(s) 11.39.57\u202fa.\xa0m..png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U06T5JSMBQQ',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 65298,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F074G847FAL/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m..png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F074G847FAL/download/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m..png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._360.png',
#     'thumb_360_w': 188,
#     'thumb_360_h': 360,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._480.png',
#     'thumb_480_w': 250,
#     'thumb_480_h': 480,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._720.png',
#     'thumb_720_w': 375,
#     'thumb_720_h': 720,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._800.png',
#     'thumb_800_w': 417,
#     'thumb_800_h': 800,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._960.png',
#     'thumb_960_w': 501,
#     'thumb_960_h': 960,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._1024.png',
#     'thumb_1024_w': 534,
#     'thumb_1024_h': 1024,
#     'original_w': 682,
#     'original_h': 1308,
#     'thumb_tiny': 'AwAwABnQMqf31/OnKyuMqwP0NJsX+6PypQoHQAfSgBsYcFt5B54p9FFADfxP5Uc+/wCVOooATn1P5UY96WigAoJxRRQAUUUUAf/Z',
#     'permalink': 'https://somoslikeu.slack.com/files/U06T5JSMBQQ/F074G847FAL/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m..png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F074G847FAL-042f2fc3ff',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'},
#    {'id': 'F073VU7HPN0',
#     'created': 1715878106,
#     'timestamp': 1715878106,
#     'name': 'Captura de pantalla 2024-05-16 a la(s) 11.40.15\u202fa.\xa0m..png',
#     'title': 'Captura de pantalla 2024-05-16 a la(s) 11.40.15\u202fa.\xa0m..png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U06T5JSMBQQ',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 58072,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F073VU7HPN0/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m..png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F073VU7HPN0/download/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m..png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._360.png',
#     'thumb_360_w': 173,
#     'thumb_360_h': 360,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._480.png',
#     'thumb_480_w': 231,
#     'thumb_480_h': 480,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._720.png',
#     'thumb_720_w': 346,
#     'thumb_720_h': 720,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._800.png',
#     'thumb_800_w': 384,
#     'thumb_800_h': 800,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._960.png',
#     'thumb_960_w': 461,
#     'thumb_960_h': 960,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073VU7HPN0-e20346d7b1/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m._1024.png',
#     'thumb_1024_w': 492,
#     'thumb_1024_h': 1024,
#     'original_w': 612,
#     'original_h': 1274,
#     'thumb_tiny': 'AwAwABfT7ikLKpwWA+ppaQqrHJUH6igBFdTxvUn2NOyPUU0RoDkIoP0pcD0FABk+lGT6UYHpS0AJk+lLRRQAUUUhA70ALRRSUAf/2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U06T5JSMBQQ/F073VU7HPN0/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m..png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F073VU7HPN0-28f81e4501',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U06T5JSMBQQ',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 's9dHD',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Buenos días team, vengo a comentarles un inconveniente que tengo. En la otra empresa donde laboro me ocuparon los jueves de 4 a 6, este tiempo lo van hacer cada dos semanas. Quería comentarles si tal vez podamos mover ese daily a otro día de la semana? cualquier día de 4 a 5 excepto los jueves yo no tengo obligaciones, quedo pendiente a sus comentarios y propuestas. '},
#        {'type': 'broadcast', 'range': 'channel'}]}]}],
#   'type': 'message',
#   'ts': '1715878417.166439',
#   'client_msg_id': '43ece527-a6d5-46c9-af65-ef0ac8b3cca7'},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715818156.096109',
#   'client_msg_id': '155c64b1-3afa-48fa-8f0c-86e80381d7d3',
#   'text': '<@U01L6UJGRSS> avanzando en el proyecto de bot me tope con que mis creditos gratis de openIA ya expiraron, puedo crear el asistente y hacer todas las configuraciones del lado de slack, pero para poder ponerlo a funcionar hay un minimo de 5 dolares',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'rrJtA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U01L6UJGRSS'},
#        {'type': 'text',
#         'text': ' avanzando en el proyecto de bot me tope con que mis creditos gratis de openIA ya expiraron, puedo crear el asistente y hacer todas las configuraciones del lado de slack, pero para poder ponerlo a funcionar hay un minimo de 5 dolares'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715814120.995919',
#   'client_msg_id': '4dbaa154-1557-457a-8fbe-d59bcd5f08cf',
#   'text': 'ya quedo',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '3qoMD',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'ya quedo'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715814088.388489',
#   'client_msg_id': '0eb91794-8f4c-42d9-9dae-9b51d662188f',
#   'text': 'listo ya voy',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'flGSz',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'listo ya voy'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U06S28H3CFR', 'U06SGR43U1G'],
#     'count': 2}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715810191.986359',
#   'client_msg_id': 'e8f933bf-bc13-4091-83c3-88f126d59988',
#   'text': 'Necesita permisos para acceder',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'm87n4',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Necesita permisos para acceder'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715810166.811679',
#   'client_msg_id': '3fc11978-e5f3-48e2-9220-7cf45d1f207d',
#   'text': 'Con cual correo deberia poder ingresar?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'adT15',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Con cual correo deberia poder ingresar?'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715810106.255539',
#   'client_msg_id': 'f3835802-0ac0-47cc-8424-8e6cf080e7f9',
#   'text': 'Clausulado Seguro de Motos Digital',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'dy9T3',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Clausulado Seguro de Motos Digital'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715810103.551719',
#   'client_msg_id': '7594b6a7-7917-40e2-ac9a-790c33b87584',
#   'text': 'Politicas_59.Autos',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'hvqHz',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Politicas_59.Autos'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715810102.789489',
#   'client_msg_id': 'b0480dae-a614-4990-8475-51ce9b1a7b37',
#   'text': 'hay dos pdf ,',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'GBKBw',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'hay dos pdf ,'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715810033.922309',
#   'client_msg_id': '00c40421-c42d-43d2-b15b-0af93989b3d6',
#   'text': 'revisa por favor si puedes ingresar',
#   'team': 'T01LAKECKEH',
#   'thread_ts': '1715810033.922309',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1715811283.194289',
#   'reply_users': ['U06S28H3CFR'],
#   'is_locked': False,
#   'subscribed': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'lIDqT',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'revisa por favor si puedes ingresar'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715810023.690779',
#   'client_msg_id': '1319589f-c941-4094-9ca3-1009f6922045',
#   'text': '<https://drive.google.com/open?id=1d-VKcKjqKn21Q4-57y3FUFlsOmdpAak-&amp;usp=drive_fs>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'IDr27',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'link',
#         'url': 'https://drive.google.com/open?id=1d-VKcKjqKn21Q4-57y3FUFlsOmdpAak-&usp=drive_fs'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715810022.925239',
#   'client_msg_id': 'b21cf1dc-1afc-4c1f-a746-8cb2a89d444b',
#   'text': 'Buenas tardes',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '7oE9R',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Buenas tardes'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715809343.413709',
#   'client_msg_id': '19f7420c-22b6-4c35-94a6-e359cee93abb',
#   'text': 'Hola equipo, <@U01L6UJGRSS> nos podes pasar porfa los documentos para generar la base de conocimiento para el bot ?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 's2THR',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hola equipo, '},
#        {'type': 'user', 'user_id': 'U01L6UJGRSS'},
#        {'type': 'text',
#         'text': ' nos podes pasar porfa los documentos para generar la base de conocimiento para el bot ?'}]}]}]},
#  {'text': 'Buenas tardes muchachos, ayer subí el código a github, tengo varias actualizaciones:\n• Ya se entreno el modelo para la clasificación de emociones con una maquina de soporte vectorial y con la ayuda de un modelo creado por meta wav2vec2; este modelo que estoy usando, tiene la característica de que se le hizo un fine tuning con data relacionada con el reconocimiento de emociones.\n• Se probo con un audio y arrojo un resultado, pero debo pre procesar mas el audio ya que es muy general, no logra capturar la emoción del momento, estaba pensando en separar el audio en audios de 10 seg para así tener concordancia con la base de datos que se uso para entrenarlo (queda a discusión ya que he visto en papers que se usan mas segundos).\n• La clave es el pre procesamiento, ya que la selección de características la elige el modelo y la clasificación de emociones también las da el modelo y muestra resultado muy prometedores como podemos ver en esta imagen, donde se compara con una biblioteca llamada openSMILE, la cual seria la equivalente a hacerlo a "mano".\n<https://github.com/lromero22/GenIA/blob/devBrandon/Training_model.ipynb>',
#   'files': [{'id': 'F073P8P3LNQ',
#     'created': 1715793461,
#     'timestamp': 1715793461,
#     'name': 'matriz de confusion.png',
#     'title': 'matriz de confusion.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U06T5JSMBQQ',
#     'user_team': 'T01LAKECKEH',
#     'editable': False,
#     'size': 58154,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': False,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F073P8P3LNQ/matriz_de_confusion.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F073P8P3LNQ/download/matriz_de_confusion.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 129,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 172,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 259,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F073P8P3LNQ-c07c726fbf/matriz_de_confusion_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 287,
#     'original_w': 871,
#     'original_h': 313,
#     'thumb_tiny': 'AwARADC9KrMQyuQV6DPB+tCSH7sgww6+n4U5lyQckYoZQ4GRnH6UxDs1HKjMQyOQy9Bng/Wml2ib5huj7EcnNTUARJNk7ZBtcd+xPtUtMeNZB8w6dD6VFveA4fLp0DDls+9AFg009qcaae1IY4UGgUGgBp7U4U09qcKAP//Z',
#     'permalink': 'https://somoslikeu.slack.com/files/U06T5JSMBQQ/F073P8P3LNQ/matriz_de_confusion.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F073P8P3LNQ-5aa75f2ec0',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U06T5JSMBQQ',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'zW+t0',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Buenas tardes muchachos, ayer subí el código a github, tengo varias actualizaciones:\n'}]},
#      {'type': 'rich_text_list',
#       'elements': [{'type': 'rich_text_section',
# ...
#     'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F072FHA4DH9-ddb4699fc5/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F072FHA4DH9-ddb4699fc5/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 239,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F072FHA4DH9-ddb4699fc5/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 319,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F072FHA4DH9-ddb4699fc5/image_160.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F072FHA4DH9-ddb4699fc5/image_720.png',
#     'thumb_720_w': 720,
#     'thumb_720_h': 479,
#     'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F072FHA4DH9-ddb4699fc5/image_800.png',
#     'thumb_800_w': 800,
#     'thumb_800_h': 532,
#     'original_w': 809,
#     'original_h': 538,
#     'thumb_tiny': 'AwAfADDSPXtSYPtTT1NAI6ZNADsH0FGD7UnHqaXA9TQAvPtS896bj3NO/GgBh6n60AnH3f0oIOT9aFzigBQfb9KXPtSZpc0AGaWiigD/2Q==',
#     'permalink': 'https://somoslikeu.slack.com/files/U06SPFKSFU2/F072FHA4DH9/image.png',
#     'permalink_public': 'https://slack-files.com/T01LAKECKEH-F072FHA4DH9-6b046de95d',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U06SPFKSFU2',
#   'display_as_bot': False,
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'K94i+',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Buenas,\nSe encontraron los siguientes resultados de los 4 primeros audios.\nAudio 4339_6: SPEAKER 1 = Liker\n\n Audio 8701_2: SPEAKER 0 = Liker\n\n Audio 9230_3: SPEAKER 0 = Liker\n\n Audio 4369_1: SPEAKER 0 = Liker\n\n\n Teniendo una identificación del 100%, el modelo entrenado normalmente ignora las entidades que no son similares a las que le fueron enseñadas, pero en otras ocasiones identifica otras provenientes del modelo base de la librería.'}]}]}],
#   'type': 'message',
#   'ts': '1715139097.348269',
#   'client_msg_id': '0238b534-fc2b-40cb-a01d-d65db34361b4'},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715119801.318369',
#   'client_msg_id': '9ad95b99-5f7b-4354-bc82-667eaca591b3',
#   'text': 'out-3103814989-913-20240404-161134-1712265094.160513.WAV dio negativo para SPEAKER_00 mediante metodo completo\nout-3118642729-913-20240405-141059-1712344259.161987.WAV dio negativo para SPEAKER_01 mediante metodo completo\nout-3118642729-913-20240405-141059-1712344259.161987.WAV dio negativo para SPEAKER_01 mediante metodo fragmentado',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NSMm4',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'out-3103814989-913-20240404-161134-1712265094.160513.WAV dio negativo para SPEAKER_00 mediante metodo completo\nout-3118642729-913-20240405-141059-1712344259.161987.WAV dio negativo para SPEAKER_01 mediante metodo completo\nout-3118642729-913-20240405-141059-1712344259.161987.WAV dio negativo para SPEAKER_01 mediante metodo fragmentado'}]}]}]},
#  {'user': 'U06T5JSMBQQ',
#   'type': 'message',
#   'ts': '1715035992.796689',
#   'client_msg_id': 'd497be63-fa7b-45f5-8537-7897f62d2aa7',
#   'text': 'Listo Leo, ya la envié desde el personal. Gracias',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Zi88K',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Listo Leo, ya la envié desde el personal. Gracias'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715035418.234389',
#   'client_msg_id': '32cdaef3-5756-4522-9e68-d19c8e9a97e0',
#   'text': 'Enviada :white_check_mark:',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'ZIOPa',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Enviada '},
#        {'type': 'emoji', 'name': 'white_check_mark', 'unicode': '2705'}]}]}]},
#  {'user': 'U06SPFKSFU2',
#   'type': 'message',
#   'ts': '1715035348.853729',
#   'client_msg_id': '4da72882-cdce-44f8-a1ac-cd8ceec61701',
#   'text': 'Yo también confirmo',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'rYWVC',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Yo también confirmo'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715035316.042309',
#   'client_msg_id': '3843afac-f27c-4ef2-988b-a0232a6b966e',
#   'text': 'recibida, ya confirmo con finanzas , si me pueden confirmas todos por favor',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '9hMRH',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'recibida, ya confirmo con finanzas , si me pueden confirmas todos por favor'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715035289.954859',
#   'client_msg_id': 'c6b16c5d-a1a3-40a2-9643-3786c1491ca9',
#   'text': 'Listo Leo, ya te le envíe desde el personal',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '2GgiJ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Listo Leo, ya te le envíe desde el personal'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715035171.740859',
#   'client_msg_id': '80f84a6b-cf85-4029-88a1-93357df2aec1',
#   'text': 'por favor',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '7WmRH',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'por favor'}]}]}]},
#  {'user': 'U06S28H3CFR',
#   'type': 'message',
#   'ts': '1715035149.561669',
#   'client_msg_id': 'dd8230ce-cbc4-40a3-9a11-2518a94b7a47',
#   'text': 'Yo igual leo, la envíe desde el somos likeU y aún no me han pagado, ya hago la gestión desde el personal',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NuP0J',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Yo igual leo, la envíe desde el somos likeU y aún no me han pagado, ya hago la gestión desde el personal'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715035111.488139',
#   'client_msg_id': '6734a9b5-b850-483f-9d46-ea3f9a890755',
#   'text': 'Vale',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'ih/0/',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Vale'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715035102.699479',
#   'edited': {'user': 'U01L6UJGRSS', 'ts': '1715035110.000000'},
#   'client_msg_id': '2414ab51-a846-42ad-9e40-770df812718b',
#   'text': '<mailto:ti@likeu.co|ti@likeu.co>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'FuBCI',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'link',
#         'url': 'mailto:ti@likeu.co',
#         'text': 'ti@likeu.co'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715035098.588049',
#   'client_msg_id': 'f7e50a1e-badc-4224-9465-5c84d95ea66c',
#   'text': 'jejeje si',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'rbgqR',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'jejeje si'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715034962.283449',
#   'client_msg_id': 'bb1bb6c1-ef47-464e-9013-f6e8337fc7ed',
#   'text': 'En cuyo caso, cual correo sería el tuyo?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '142da',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'En cuyo caso, cual correo sería el tuyo?'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715034953.137409',
#   'client_msg_id': 'ddbba183-975c-4ffd-b777-931f5b8a1178',
#   'text': 'Te colocamos como copia de carbono?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '98bPJ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Te colocamos como copia de carbono?'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715034951.796209',
#   'client_msg_id': '45c8a831-ca71-4075-971a-d4a0536ca551',
#   'text': 'pues el proceso ...',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'm4urn',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'pues el proceso ...'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715034940.423869',
#   'client_msg_id': '5170cd5e-a4ec-41f1-8f39-d87d59e36cf5',
#   'text': '<@U06T5JSMBQQ> y <@U06S28H3CFR> ???',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '6n4Uh',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U06T5JSMBQQ'},
#        {'type': 'text', 'text': ' y '},
#        {'type': 'user', 'user_id': 'U06S28H3CFR'},
#        {'type': 'text', 'text': ' ???'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715034918.376229',
#   'client_msg_id': 'ef7f4317-cc9d-4e78-bc69-5c80eed3c39e',
#   'text': 'me copian y yo le hago l a gestión',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'GxVIc',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'me copian y yo le hago l a gestión'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715034905.858789',
#   'client_msg_id': 'a8ff8e64-df56-444d-8dfb-f83d9a5a70b5',
#   'text': 'si por favor',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'GP2xB',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'si por favor'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715034849.553099',
#   'client_msg_id': '41db1467-d7ab-4768-82ca-7157f956189e',
#   'text': 'Siempre la enviamos por el personal?',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'vtmh9',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Siempre la enviamos por el personal?'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715034744.562999',
#   'edited': {'user': 'U01L6UJGRSS', 'ts': '1715034753.000000'},
#   'client_msg_id': 'c4600796-1655-4f85-b99c-3eab4ffdb27d',
#   'text': 'por favor la envian desde el correo personal',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'wyhMN',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'por favor la envian desde el correo personal'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U06SGR43U1G'],
#     'count': 1},
#    {'name': 'face_in_clouds', 'users': ['U06SPFKSFU2'], 'count': 1}]},
#  {'user': 'U06SPFKSFU2',
#   'type': 'message',
#   'ts': '1715033948.543989',
#   'client_msg_id': '1baa9cc6-fa4a-456b-b341-467d60ad4895',
#   'text': 'A mi tampoco, y envié la cuenta a estos dos\n<mailto:dosoperaciones@likeu.co|operaciones@likeu.co> y <mailto:ti@likeu.co|ti@likeu.co>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'h0rDb',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'A mi tampoco, y envié la cuenta a estos dos\n'},
#        {'type': 'link',
#         'url': 'mailto:dosoperaciones@likeu.co',
#         'text': 'operaciones@likeu.co'},
#        {'type': 'text', 'text': ' y '},
#        {'type': 'link',
#         'url': 'mailto:ti@likeu.co',
#         'text': 'ti@likeu.co'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715033878.466509',
#   'client_msg_id': '269ff502-f434-4964-a213-75c6c972c5eb',
#   'text': 'Envíe mi cuenta de cobro al correo <mailto:operaciones@likeu.co|operaciones@likeu.co>',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'OY6TN',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Envíe mi cuenta de cobro al correo '},
#        {'type': 'link',
#         'url': 'mailto:operaciones@likeu.co',
#         'text': 'operaciones@likeu.co'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715033858.580659',
#   'client_msg_id': '00f2989d-211d-420e-b311-3ec0346a2f63',
#   'text': 'A mí no me han pagado',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'pFQMW',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'A mí no me han pagado'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715033773.935249',
#   'client_msg_id': '5e3916e3-97c9-4d01-adf5-ad7938d7218d',
#   'text': '<!channel>, como les fue con el pago ???',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'ctYD4',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text', 'text': ', como les fue con el pago ???'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1715022831.199309',
#   'client_msg_id': '6dc348dc-7c85-4ba8-8334-37956eb5ce51',
#   'text': 'A mi se me complica mas tarde , hagámosla a las 4:30  y <@U06SPFKSFU2> cuando puedas nos dejas por acá el resumen de tus actividades y resultados,  ya lo miramos el Jueves',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'rJ5G9',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'A mi se me complica mas tarde , hagámosla a las 4:30  y '},
#        {'type': 'user', 'user_id': 'U06SPFKSFU2'},
#        {'type': 'text',
#         'text': ' cuando puedas nos dejas por acá el resumen de tus actividades y resultados,  ya lo miramos el Jueves'}]}]}]},
#  {'user': 'U06SGR43U1G',
#   'type': 'message',
#   'ts': '1715021543.009359',
#   'client_msg_id': '6843a63f-5f3e-4e9d-9ae4-45837cb1a4fa',
#   'text': 'Yo personalmente podria asistir un poco más tarde u otro día',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '9x4jL',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Yo personalmente podria asistir un poco más tarde u otro día'}]}]}]},
#  {'user': 'U06SPFKSFU2',
#   'type': 'message',
#   'ts': '1715013825.240409',
#   'client_msg_id': '93ab1a9a-0d3c-41f3-895e-861669d2f43e',
#   'text': '<!channel> Buenos días,\n\nVengo con una solicitud, podemos mover la reunión de mañana para más tarde? O cambiarla de día?\n\nMañana no podré asistir :/',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Xt4ul',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'broadcast', 'range': 'channel'},
#        {'type': 'text',
#         'text': ' Buenos días,\n\nVengo con una solicitud, podemos mover la reunión de mañana para más tarde? O cambiarla de día?\n\nMañana no podré asistir :/'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1714744834.903199',
#   'client_msg_id': 'eead19c2-c56d-4535-8874-9add001f92d3',
#   'text': 'Se estan subiendo en este momento , son  como 230',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '2Ss9N',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Se estan subiendo en este momento , son  como 230'}]}]}]},
#  {'user': 'U01L6UJGRSS',
#   'type': 'message',
#   'ts': '1714744770.398119',
#   'client_msg_id': '058109cc-7d0b-456d-8472-fdacc44bfbf0',
#   'text': 'enlace con audios',
#   'team': 'T01LAKECKEH',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'wCXfS',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'enlace con audios'}]}]}],
#   'reactions': [{'name': 'white_check_mark',
#     'users': ['U06SGR43U1G', 'U06S28H3CFR', 'U06SPFKSFU2'],
#     'count': 3}]}]

# %%
for i in szs:
    if 'files' in i:
        file = i.get('files')
        if len(file) == 1:
            extension = file[0].get('filetype')
            if extension in ['png', 'jpg', 'jpeg', 'jfif', 'pjpeg', 'pjp']:
                print(True)
                continue
            else:
                print(False)
        else:
            print(i)
# Out:
# True
# True
# True
# True
# False
# {'text': 'Buenos días team, vengo a comentarles un inconveniente que tengo. En la otra empresa donde laboro me ocuparon los jueves de 4 a 6, este tiempo lo van hacer cada dos semanas. Quería comentarles si tal vez podamos mover ese daily a otro día de la semana? cualquier día de 4 a 5 excepto los jueves yo no tengo obligaciones, quedo pendiente a sus comentarios y propuestas. <!channel>', 'files': [{'id': 'F074G847FAL', 'created': 1715878102, 'timestamp': 1715878102, 'name': 'Captura de pantalla 2024-05-16 a la(s) 11.39.57\u202fa.\xa0m..png', 'title': 'Captura de pantalla 2024-05-16 a la(s) 11.39.57\u202fa.\xa0m..png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U06T5JSMBQQ', 'user_team': 'T01LAKECKEH', 'editable': False, 'size': 65298, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F074G847FAL/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m..png', 'url_private_download': 'https://files.slack.com/files-pri/T01LAKECKEH-F074G847FAL/download/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m..png', 'media_display_type': 'unknown', 'thumb_64': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._64.png', 'thumb_80': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._80.png', 'thumb_360': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._360.png', 'thumb_360_w': 188, 'thumb_360_h': 360, 'thumb_480': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._480.png', 'thumb_480_w': 250, 'thumb_480_h': 480, 'thumb_160': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._160.png', 'thumb_720': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._720.png', 'thumb_720_w': 375, 'thumb_720_h': 720, 'thumb_800': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._800.png', 'thumb_800_w': 417, 'thumb_800_h': 800, 'thumb_960': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._960.png', 'thumb_960_w': 501, 'thumb_960_h': 960, 'thumb_1024': 'https://files.slack.com/files-tmb/T01LAKECKEH-F074G847FAL-9a8f4dbe90/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m._1024.png', 'thumb_1024_w': 534, 'thumb_1024_h': 1024, 'original_w': 682, 'original_h': 1308, 'thumb_tiny': 'AwAwABnQMqf31/OnKyuMqwP0NJsX+6PypQoHQAfSgBsYcFt5B54p9FFADfxP5Uc+/wCVOooATn1P5UY96WigAoJxRRQAUUUUAf/Z', 'permalink': 'https://somoslikeu.slack.com/files/U06T5JSMBQQ/F074G847FAL/captura_de_pantalla_2024-05-16_a_la_s__11.39.57___a.__m..png', 'permalink_public': 'https://slack-files.com/T01LAKECKEH-F074G847FAL-042f2fc3ff', 'is_starred': False, 'has_rich_preview': False, 'file_access': 'visible'}, {'id': 'F073VU7HPN0', 'created': 1715878106, 'timestamp': 1715878106, 'name': 'Captura de pantalla 2024-05-16 a la(s) 11.40.15\u202fa.\xa0m..png', 'title': 'Captura de pantalla 2024-05-16 a la(s) 11.40.15\u202fa.\xa0m..png', 'mimetype': 'image/png', 'filetype': 'png', 'pretty_type': 'PNG', 'user': 'U06T5JSMBQQ', 'user_team': 'T01LAKECKEH', 'editable': False, 'size': 58072, 'mode': 'hosted', 'is_external': False, 'external_type': '', 'is_public': False, 'public_url_shared': False, 'display_as_bot': False, 'username': '', 'url_private': 'https://files.slack.com/files-pri/T01LAKECKEH-F073VU7HPN0/captura_de_pantalla_2024-05-16_a_la_s__11.40.15___a.__m..png', 'url_private_download': 'https://files.slac ...
# True
# True
# True
# False
# True

# %%
for i in szs:
  if "attachments" in i:
    print(i.get('text'))
# Out:
# Buenas tardes muchachos, ayer subí el código a github, tengo varias actualizaciones:
# • Ya se entreno el modelo para la clasificación de emociones con una maquina de soporte vectorial y con la ayuda de un modelo creado por meta wav2vec2; este modelo que estoy usando, tiene la característica de que se le hizo un fine tuning con data relacionada con el reconocimiento de emociones.
# • Se probo con un audio y arrojo un resultado, pero debo pre procesar mas el audio ya que es muy general, no logra capturar la emoción del momento, estaba pensando en separar el audio en audios de 10 seg para así tener concordancia con la base de datos que se uso para entrenarlo (queda a discusión ya que he visto en papers que se usan mas segundos).
# • La clave es el pre procesamiento, ya que la selección de características la elige el modelo y la clasificación de emociones también las da el modelo y muestra resultado muy prometedores como podemos ver en esta imagen, donde se compara con una biblioteca llamada openSMILE, la cual seria la equivalente a hacerlo a "mano".
# <https://github.com/lromero22/GenIA/blob/devBrandon/Training_model.ipynb>
# <https://platform.openai.com/docs/assistants/overview>
# <https://github.com/lromero22/GenIA/blob/devOscar/src/keyword_process.ipynb>

# %%
'      '.strip()
# Out:
# ''
