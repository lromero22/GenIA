# %% [markdown]
# # WhisperX
# * Enlace del paper: https://arxiv.org/pdf/2303.00747.pdf
# * Enlace del repositorio de GitHub: https://github.com/m-bain/whisperX
# * Enlace de HuggingFace para pyannote: https://huggingface.co/pyannote/speaker-diarization-3.1

# %%
import os
import whisper
import torch
import pandas as pd
from operator import itemgetter

# %% [markdown]
# # Audio de 10 minutos

# %%
import whisperx
import gc 

device = "cuda" 
audio_file = "1001764369_1.WAV"
batch_size = 16 # reduce if low on GPU mem
compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)

# 1. Transcribe with original whisper (batched)
model = whisperx.load_model("large-v2", device, compute_type = compute_type, language = "es")

# save model to local path (optional)
# model_dir = "/path/"
# model = whisperx.load_model("large-v2", device, compute_type=compute_type, download_root=model_dir)

audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size = batch_size, language = "es")
print(result["segments"]) # before alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model

# 2. Align whisper output
model_a, metadata = whisperx.load_align_model(language_code = result["language"], device = device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments = False)

print(result["segments"]) # after alignment

# delete model if low on GPU resources
# import gc; gc.collect(); torch.cuda.empty_cache(); del model_a

# 3. Assign speaker labels
diarize_model = whisperx.DiarizationPipeline(use_auth_token="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", device = device)

# add min/max number of speakers if known
diarize_segments = diarize_model(audio, num_speakers = 2)
# diarize_model(audio, min_speakers=min_speakers, max_speakers=max_speakers)

result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
# WARNING:tensorflow:From c:\Users\usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyannote\audio\core\io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\usuario\.cache\torch\whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.2+cu118. Bad things might happen unless you revert torch to 1.x.
# [{'text': ' Hola. Sí, buenas tardes. Sí, con Juan Cartagena. Sí. Hola. Hola. ¿Cómo estás? Muy bien. Ay, qué bueno. Me alegro. Juan, vimos en nuestro sistema tu interés por asegurar tu moto con la policía a todo riesgo, con placas RKQ33F. ¿Es correcto? Sí. Listo, Juan. Y cuando ingresaste al sistema, ¿pudiste ver los valores? Hola.', 'start': 10.742, 'end': 38.063}, {'text': ' Cuando ingresaste al sistema, ¿pudiste ver los valores? Sí, más o menos. Listo, Juan. ¿Hay alguno que te llamara la atención? ¿Me puedes repetir los valores, por favor? Sí, claro que sí. Te pregunto, Juan. ¿Tú eres el que aparece en la tarjeta de propiedad? Sí. Listo. En un momento, entonces, para que podamos realizar la cotización. Te voy entonces a confirmar tu fecha de nacimiento,', 'start': 39.002, 'end': 66.101}, {'text': ' tengo que es 28.9 del 2000, ¿está bien? Sí. Un momento. Te pregunto, ¿la moto es de uso personal o trabajo? Sí, es uso personal solamente para mí. Y ¿cuál sería la ciudad de mayor circulación de la moto? Yo estoy en Río Negro.', 'start': 66.527, 'end': 90.674}, {'text': ' ¿Listo? Tengo segura modelo 2021 Suzuki TR150. ¿Está bien? Sí. Sí. Entonces, mira, seguro sobre segura tu moto en un valor de $7,200,000. ¿Qué te va a pedir la póliza con nosotros? Una responsabilidad civil o unos daños a terceros por un valor de $840,000,000 de pesos para cada evento. Esta cobertura es la más importante porque una persona hasta podría perder su patrimonio si digamos con su v
.057, 'end': 30.357, 'score': 0.192}]}, {'start': 30.537, 'end': 31.898, 'text': '¿Es correcto?', 'words': [{'word': '¿Es', 'start': 30.537, 'end': 30.657, 'score': 0.834}, {'word': 'correcto?', 'start': 31.438, 'end': 31.898, 'score': 0.936}]}, {'start': 32.599, 'end': 34.02, 'text': 'Sí.', 'words': [{'word': 'Sí.', 'start': 32.599, 'end': 34.02, 'score': 0.756}]}, {'start': 34.06, 'end': 34.4, 'text': 'Listo, Juan.', 'words': [{'word': 'Listo,', 'start': 34.06, 'end': 34.26, 'score': 0.661}, {'word': 'Juan.', 'start': 34.3, ' ...
#                                segment label     speaker       start  \
# 0    [ 00:00:10.704 -->  00:00:11.027]     A  SPEAKER_00   10.704584
# 1    [ 00:00:11.910 -->  00:00:14.202]     B  SPEAKER_01   11.910017
# 2    [ 00:00:15.169 -->  00:00:15.543]     C  SPEAKER_00   15.169779
# 3    [ 00:00:16.765 -->  00:00:17.529]     D  SPEAKER_01   16.765705
# 4    [ 00:00:17.682 -->  00:00:19.414]     E  SPEAKER_01   17.682513
# ..                                 ...   ...         ...         ...
# 187  [ 00:09:52.351 -->  00:09:53.353]    GF  SPEAKER_00  592.351443
# 188  [ 00:09:53.981 -->  00:09:56.918]    GG  SPEAKER_01  593.981324
# 189  [ 00:09:54.032 -->  00:09:54.575]    GH  SPEAKER_00  594.032258
# 190  [ 00:09:58.089 -->  00:09:58.853]    GI  SPEAKER_00  598.089983
# 191  [ 00:09:58.853 -->  00:09:59.906]    GJ  SPEAKER_01  598.853990
#
#             end  intersection       union
# 0     11.027165   -588.628835  589.177416
# 1     14.202037   -585.453963  587.971983
# 2     15.543294   -584.112706  584.712221
# 3     17.529711   -582.126289  583.116295
# 4     19.414261   -580.241739  582.199487
# ..          ...           ...         ...
# 187  593.353141     -6.302859    7.530557
# 188  596.918506     -2.737494    5.900676
# 189  594.575552     -5.080448    5.849742
# 190  598.853990     -0.802010    1.792017
# 191  599.906621      0.226000    1.052632
#
# [192 rows x 7 columns]
# [{'start': 10.742, 'end': 10.922, 'text': ' Hola.', 'words': [{'word': 'Hola.', 'start': 10.742, 'end': 10.922, 'score': 0.289, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}, {'start': 11.042, 'end': 13.244, 'text': 'Sí, buenas tardes.', 'words': [{'word': 'Sí,', 'start': 11.042, 'end': 12.103, 'score': 0.763, 'speaker': 'SPEAKER_01'}, {'word': 'buenas', 'start': 12.123, 'end': 12.343, 'score': 0.504, 'speaker': 'SPEAKER_01'}, {'word': 'tardes.', 'start': 13.064, 'end': 13.244, 'score': 0.218, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 13.264, 'end': 14.105, 'text': 'Sí, con Juan Cartagena.', 'words': [{'word': 'Sí,', 'start': 13.264, 'end': 13.304, 'score': 0.017, 'speaker': 'SPEAKER_01'}, {'word': 'con', 'start': 13.324, 'end': 13.384, 'score': 0.172, 'speaker': 'SPEAKER_01'}, {'word': 'Juan', 'start': 13.404, 'end': 13.504, 'score': 0.306, 'speaker': 'SPEAKER_01'}, {'word': 'Cartagena.', 'start': 13.544, 'end': 14.105, 'score': 0.896, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start':
scores = []
for segment in result["segments"]:
    # Filtrar solo las palabras que tienen un puntaje válido
    words_with_scores = [word for word in segment["words"] if "score" in word]
    # Calcular el puntaje promedio para las palabras filtradas
    if words_with_scores:
        avg_score = pd.DataFrame(words_with_scores)["score"].mean()
    else:
        avg_score = float("nan")  # Otra opción: avg_score = None
    scores.append(avg_score)

scores = pd.Series(scores, name = "avg_score")
scores
# Out:
# 0      0.289000
# 1      0.495000
# 2      0.347750
# 3      0.217000
# 4      0.533000
#          ...
# 165    0.287000
# 166    0.325000
# 167    0.438364
# 168    0.247500
# 169    0.380750
# Name: avg_score, Length: 170, dtype: float64

# %%
result["segments"]
# Out:
# [{'start': 10.742,
#   'end': 10.922,
#   'text': ' Hola.',
#   'words': [{'word': 'Hola.',
#     'start': 10.742,
#     'end': 10.922,
#     'score': 0.289,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 11.042,
#   'end': 13.244,
#   'text': 'Sí, buenas tardes.',
#   'words': [{'word': 'Sí,',
#     'start': 11.042,
#     'end': 12.103,
#     'score': 0.763,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'buenas',
#     'start': 12.123,
#     'end': 12.343,
#     'score': 0.504,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tardes.',
#     'start': 13.064,
#     'end': 13.244,
#     'score': 0.218,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 13.264,
#   'end': 14.105,
#   'text': 'Sí, con Juan Cartagena.',
#   'words': [{'word': 'Sí,',
#     'start': 13.264,
#     'end': 13.304,
#     'score': 0.017,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 13.324,
#     'end': 13.384,
#     'score': 0.172,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Juan',
#     'start': 13.404,
#     'end': 13.504,
#     'score': 0.306,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Cartagena.',
#     'start': 13.544,
#     'end': 14.105,
#     'score': 0.896,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 17.988,
#   'end': 18.248,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 17.988,
#     'end': 18.248,
#     'score': 0.217,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 18.388,
#   'end': 18.608,
#   'text': 'Hola.',
#   'words': [{'word': 'Hola.',
#     'start': 18.388,
#     'end': 18.608,
#     'score': 0.533,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 18.628,
#   'end': 18.808,
#   'text': 'Hola.',
#   'words': [{'word': 'Hola.',
#     'start': 18.628,
#     'end': 18.808,
#     'score': 0.582,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 18.848,
#   'end': 19.369,
#   'text': '¿Cómo estás?',
#   'words': [{'word': '¿Cómo',
#     'start': 18.848,
#     'end': 18.988,
#     'score': 0.397,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'estás?',
#     'start': 19.028,
#     'end': 19.369,
#     'score': 0.625,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 20.329,
#   'end': 22.191,
#   'text': 'Muy bien.',
#   'words': [{'word': 'Muy',
#     'start': 20.329,
#     'end': 20.409,
#     'score': 0.176,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'bien.',
#     'start': 20.449,
#     'end': 22.191,
#     'score': 0.479,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 22.231,
#   'end': 22.831,
#   'text': 'Ay, qué bueno.',
#   'words': [{'word': 'Ay,',
#     'start': 22.231,
#     'end': 22.311,
#     'score': 0.379,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'qué',
#     'start': 22.331,
#     'end': 22.431,
#     'score': 0.615,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'bueno.',
#     'start': 22.471,
#     'end': 22.831,
#     'score': 0.623,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 22.871,
#   'end': 23.512,
#   'text': 'Me alegro.',
#   'words': [{'word': 'Me',
#     'start': 22.871,
#     'end': 22.931,
#     'score': 0.774,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'alegro.',
#     'start': 22.991,
#     'end': 23.512,
#     'score': 0.753,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 24.012,
#   'end': 30.357,
#   'text': 'Juan, vimos en nuestro sistema tu interés por asegurar tu moto con la policía a todo riesgo, con placas RKQ33F.',
#   'words': [{'word': 'Juan,',
#     'start': 24.012,
#     'end': 24.212,
#     'score': 0.368,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'vimos',
#     'start': 24.232,
#     'end': 24.413,
#     'score': 0.52,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 24.473,
#     'end': 24.513,
#     'score': 0.342,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'nuestro',
#     'start': 24.533,
#     'end': 24.773,
#     'score': 0.696,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sistema',
#     'start': 24.813,
#     'end': 25.133,
#     'score': 0.78,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 25.173,
#     'end': 25.273,
#     'score': 0.57,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'interés',
#     'start': 25.293,
#     'end': 25.553,
#     'score': 0.644,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'por',
#     'start': 25.593,
#     'end': 25.714,
#     'score': 0.796,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'asegurar',
#     'start': 25.734,
#     'end': 26.194,
#     'score': 0.757,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 26.234,
#     'end': 26.354,
#     'score': 0.833,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moto',
#     'start': 26.374,
#     'end': 26.714,
#     'score': 0.888,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 26.754,
#     'end': 26.854,
#     'score': 0.928,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 26.894,
#     'end': 26.954,
#     'score': 0.804,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'policía',
#     'start': 27.015,
#     'end': 27.315,
#     'score': 0.565,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 27.335,
#     'end': 27.355,
#     'score': 0.056,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'todo',
#     'start': 27.395,
#     'end': 27.595,
#     'score': 0.967,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'riesgo,',
#     'start': 27.675,
#     'end': 28.155,
#     'score': 0.757,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 28.255,
#     'end': 28.396,
#     'score': 0.704,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'placas',
#     'start': 28.436,
#     'end': 29.937,
#     'score': 0.722,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'RKQ33F.',
#     'start': 30.057,
#     'end': 30.357,
#     'score': 0.192,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 30.537,
#   'end': 31.898,
#   'text': '¿Es correcto?',
#   'words': [{'word': '¿Es',
#     'start': 30.537,
#     'end': 30.657,
#     'score': 0.834,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'correcto?',
#     'start': 31.438,
#     'end': 31.898,
#     'score': 0.936,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 32.599,
#   'end': 34.02,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 32.599,
#     'end': 34.02,
#     'score': 0.756,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 34.06,
#   'end': 34.4,
#   'text': 'Listo, Juan.',
#   'words': [{'word': 'Listo,',
#     'start': 34.06,
#     'end': 34.26,
#     'score': 0.661,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Juan.',
#     'start': 34.3,
#     'end': 34.4,
#     'score': 0.503,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 34.44,
#   'end': 36.502,
#   'text': 'Y cuando ingresaste al sistema, ¿pudiste ver los valores?',
#   'words': [{'word': 'Y',
#     'start': 34.44,
#     'end': 34.48,
#     'score': 0.637,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cuando',
#     'start': 34.52,
#     'end': 34.66,
#     'score': 0.453,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ingresaste',
#     'start': 34.68,
#     'end': 34.981,
#     'score': 0.424,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'al',
#     'start': 35.041,
#     'end': 35.101,
#     'score': 0.277,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sistema,',
#     'start': 35.121,
#     'end': 35.461,
#     'score': 0.691,
#     'speaker': 'SPEAKER_01'},
#    {'word': '¿pudiste',
#     'start': 35.501,
#     'end': 35.801,
#     'score': 0.528,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ver',
#     'start': 35.841,
#     'end': 35.941,
#     'score': 0.643,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'los',
#     'start': 36.001,
#     'end': 36.081,
#     'score': 0.787,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'valores?',
#     'start': 36.142,
#     'end': 36.502,
#     'score': 0.854,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 37.783,
#   'end': 37.943,
#   'text': 'Hola.',
#   'words': [{'word': 'Hola.',
#     'start': 37.783,
#     'end': 37.943,
#     'score': 0.367,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 39.002,
#   'end': 41.164,
#   'text': ' Cuando ingresaste al sistema, ¿pudiste ver los valores?',
#   'words': [{'word': 'Cuando',
#     'start': 39.002,
#     'end': 39.262,
#     'score': 0.167,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ingresaste',
#     'start': 39.302,
#     'end': 39.642,
#     'score': 0.206,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'al',
#     'start': 39.662,
#     'end': 39.723,
#     'score': 0.288,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sistema,',
#     'start': 39.743,
#     'end': 40.143,
#     'score': 0.418,
#     'speaker': 'SPEAKER_01'},
#    {'word': '¿pudiste',
#     'start': 40.163,
#     'end': 40.443,
#     'score': 0.408,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ver',
#     'start': 40.503,
#     'end': 40.603,
#     'score': 0.714,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'los',
#     'start': 40.663,
#     'end': 40.763,
#     'score': 0.83,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'valores?',
#     'start': 40.803,
#     'end': 41.164,
#     'score': 0.922,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 42.625,
#   'end': 43.345,
#   'text': 'Sí, más o menos.',
#   'words': [{'word': 'Sí,',
#     'start': 42.625,
#     'end': 42.785,
#     'score': 0.606,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'más',
#     'start': 42.805,
#     'end': 42.905,
#     'score': 0.334,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'o',
#     'start': 42.965,
#     'end': 43.025,
#     'score': 0.641,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'menos.',
#     'start': 43.045,
#     'end': 43.345,
#     'score': 0.615,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 44.426,
#   'end': 44.886,
#   'text': 'Listo, Juan.',
#   'words': [{'word': 'Listo,',
#     'start': 44.426,
#     'end': 44.686,
#     'score': 0.731,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Juan.',
#     'start': 44.706,
#     'end': 44.886,
#     'score': 0.398,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 45.046,
#   'end': 46.627,
#   'text': '¿Hay alguno que te llamara la atención?',
#   'words': [{'word': '¿Hay',
#     'start': 45.046,
#     'end': 45.186,
#     'score': 0.496,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'alguno',
#     'start': 45.346,
#     'end': 45.607,
#     'score': 0.736,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 45.627,
#     'end': 45.707,
#     'score': 0.796,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 45.727,
#     'end': 45.787,
#     'score': 0.705,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'llamara',
#     'start': 45.827,
#     'end': 46.087,
#     'score': 0.855,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 46.127,
#     'end': 46.167,
#     'score': 0.99,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'atención?',
#     'start': 46.187,
#     'end': 46.627,
#     'score': 0.839,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 51.391,
#   'end': 53.452,
#   'text': '¿Me puedes repetir los valores, por favor?',
#   'words': [{'word': '¿Me',
#     'start': 51.391,
#     'end': 51.471,
#     'score': 0.515,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'puedes',
#     'start': 51.511,
#     'end': 51.711,
#     'score': 0.386,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'repetir',
#     'start': 51.751,
#     'end': 51.931,
#     'score': 0.198,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'los',
#     'start': 51.971,
#     'end': 52.031,
#     'score': 0.225,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'valores,',
#     'start': 52.051,
#     'end': 52.351,
#     'score': 0.626,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'por',
#     'start': 52.411,
#     'end': 52.491,
#     'score': 0.356,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'favor?',
#     'start': 52.511,
#     'end': 53.452,
#     'score': 0.528,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 53.472,
#   'end': 54.193,
#   'text': 'Sí, claro que sí.',
#   'words': [{'word': 'Sí,',
#     'start': 53.472,
#     'end': 53.592,
#     'score': 0.478,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'claro',
#     'start': 53.632,
#     'end': 53.852,
#     'score': 0.682,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 53.892,
#     'end': 53.972,
#     'score': 0.703,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sí.',
#     'start': 53.993,
#     'end': 54.193,
#     'score': 0.578,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 54.213,
#   'end': 54.973,
#   'text': 'Te pregunto, Juan.',
#   'words': [{'word': 'Te',
#     'start': 54.213,
#     'end': 54.333,
#     'score': 0.512,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pregunto,',
#     'start': 54.373,
#     'end': 54.733,
#     'score': 0.513,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Juan.',
#     'start': 54.753,
#     'end': 54.973,
#     'score': 0.565,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 55.594,
#   'end': 57.135,
#   'text': '¿Tú eres el que aparece en la tarjeta de propiedad?',
#   'words': [{'word': '¿Tú',
#     'start': 55.594,
#     'end': 55.634,
#     'score': 0.04,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'eres',
#     'start': 55.654,
#     'end': 55.794,
#     'score': 0.216,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'el',
#     'start': 55.814,
#     'end': 55.854,
#     'score': 0.054,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 55.874,
#     'end': 55.934,
#     'score': 0.909,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'aparece',
#     'start': 55.954,
#     'end': 56.134,
#     'score': 0.365,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 56.154,
#     'end': 56.194,
#     'score': 0.065,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 56.214,
#     'end': 56.274,
#     'score': 0.438,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tarjeta',
#     'start': 56.294,
#     'end': 56.554,
#     'score': 0.681,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 56.574,
#     'end': 56.654,
#     'score': 0.363,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'propiedad?',
#     'start': 56.674,
#     'end': 57.135,
#     'score': 0.825,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 57.795,
#   'end': 58.035,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 57.795,
#     'end': 58.035,
#     'score': 0.722,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 59.136,
#   'end': 59.436,
#   'text': 'Listo.',
#   'words': [{'word': 'Listo.',
#     'start': 59.136,
#     'end': 59.436,
#     'score': 0.489,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 59.476,
#   'end': 62.518,
#   'text': 'En un momento, entonces, para que podamos realizar la cotización.',
#   'words': [{'word': 'En',
#     'start': 59.476,
#     'end': 59.556,
#     'score': 0.497,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 59.596,
#     'end': 59.656,
#     'score': 0.241,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'momento,',
#     'start': 59.676,
#     'end': 59.837,
#     'score': 0.126,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'entonces,',
#     'start': 59.857,
#     'end': 60.177,
#     'score': 0.544,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'para',
#     'start': 60.237,
#     'end': 60.337,
#     'score': 0.946,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 60.397,
#     'end': 60.477,
#     'score': 0.902,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'podamos',
#     'start': 60.517,
#     'end': 60.777,
#     'score': 0.841,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'realizar',
#     'start': 60.877,
#     'end': 61.518,
#     'score': 0.82,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 61.538,
#     'end': 61.578,
#     'score': 0.006,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cotización.',
#     'start': 61.858,
#     'end': 62.518,
#     'score': 0.704,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 63.119,
#   'end': 65.941,
#   'text': 'Te voy entonces a confirmar tu fecha de nacimiento,',
#   'words': [{'word': 'Te',
#     'start': 63.119,
#     'end': 63.239,
#     'score': 0.58,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'voy',
#     'start': 63.259,
#     'end': 63.379,
#     'score': 0.447,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'entonces',
#     'start': 63.419,
#     'end': 63.699,
#     'score': 0.355,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 63.719,
#     'end': 63.739,
#     'score': 0.635,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'confirmar',
#     'start': 63.779,
#     'end': 64.38,
#     'score': 0.775,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 64.5,
#     'end': 64.74,
#     'score': 0.878,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'fecha',
#     'start': 64.76,
#     'end': 65.16,
#     'score': 0.521,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 65.18,
#     'end': 65.28,
#     'score': 0.534,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'nacimiento,',
#     'start': 65.32,
#     'end': 65.941,
#     'score': 0.884,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 66.727,
#   'end': 69.948,
#   'text': ' tengo que es 28.9 del 2000, ¿está bien?',
#   'words': [{'word': 'tengo',
#     'start': 66.727,
#     'end': 68.328,
#     'score': 0.653,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 68.348,
#     'end': 68.708,
#     'score': 0.328,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'es',
#     'start': 68.728,
#     'end': 68.768,
#     'score': 0.003,
#     'speaker': 'SPEAKER_01'},
#    {'word': '28.9'},
#    {'word': 'del',
#     'start': 68.808,
#     'end': 68.868,
#     'score': 0.035,
#     'speaker': 'SPEAKER_01'},
#    {'word': '2000,'},
#    {'word': '¿está',
#     'start': 68.908,
#     'end': 69.708,
#     'score': 0.566,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'bien?',
#     'start': 69.748,
#     'end': 69.948,
#     'score': 0.736,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 70.548,
#   'end': 70.768,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 70.548,
#     'end': 70.768,
#     'score': 0.82,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 72.369,
#   'end': 73.449,
#   'text': 'Un momento.',
#   'words': [{'word': 'Un', 'start': 72.369, 'end': 72.469, 'score': 0.503},
#    {'word': 'momento.', 'start': 72.489, 'end': 73.449, 'score': 0.596}]},
#  {'start': 73.489,
#   'end': 75.99,
#   'text': 'Te pregunto, ¿la moto es de uso personal o trabajo?',
#   'words': [{'word': 'Te',
#     'start': 73.489,
#     'end': 73.589,
#     'score': 0.378,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pregunto,',
#     'start': 73.629,
#     'end': 73.989,
#     'score': 0.827,
#     'speaker': 'SPEAKER_01'},
#    {'word': '¿la',
#     'start': 74.049,
#     'end': 74.109,
#     'score': 0.942,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moto',
#     'start': 74.169,
#     'end': 74.329,
#     'score': 0.768,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'es',
#     'start': 74.349,
#     'end': 74.429,
#     'score': 0.286,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 74.469,
#     'end': 74.549,
#     'score': 0.831,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'uso',
#     'start': 74.629,
#     'end': 74.829,
#     'score': 0.762,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'personal',
#     'start': 74.929,
#     'end': 75.47,
#     'score': 0.903,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'o',
#     'start': 75.49,
#     'end': 75.51,
#     'score': 0.001,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'trabajo?',
#     'start': 75.57,
#     'end': 75.99,
#     'score': 0.83,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 77.11,
#   'end': 80.051,
#   'text': 'Sí, es uso personal solamente para mí.',
#   'words': [{'word': 'Sí,',
#     'start': 77.11,
#     'end': 77.33,
#     'score': 0.526,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'es',
#     'start': 77.35,
#     'end': 77.39,
#     'score': 0.238,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'uso',
#     'start': 77.47,
#     'end': 77.69,
#     'score': 0.652,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'personal',
#     'start': 77.71,
#     'end': 78.05,
#     'score': 0.824,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'solamente',
#     'start': 78.07,
#     'end': 78.47,
#     'score': 0.784,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'para',
#     'start': 78.57,
#     'end': 78.671,
#     'score': 0.312,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'mí.',
#     'start': 78.691,
#     'end': 80.051,
#     'score': 0.791,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 80.811,
#   'end': 83.332,
#   'text': 'Y ¿cuál sería la ciudad de mayor circulación de la moto?',
#   'words': [{'word': 'Y',
#     'start': 80.811,
#     'end': 80.851,
#     'score': 0.953,
#     'speaker': 'SPEAKER_01'},
#    {'word': '¿cuál',
#     'start': 80.911,
#     'end': 81.051,
#     'score': 0.77,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sería',
#     'start': 81.071,
#     'end': 81.311,
#     'score': 0.714,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 81.371,
#     'end': 81.451,
#     'score': 0.863,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ciudad',
#     'start': 81.531,
#     'end': 81.791,
#     'score': 0.648,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 81.831,
#     'end': 81.911,
#     'score': 0.876,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'mayor',
#     'start': 81.931,
#     'end': 82.212,
#     'score': 0.445,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'circulación',
#     'start': 82.252,
#     'end': 82.792,
#     'score': 0.787,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 82.812,
#     'end': 82.892,
#     'score': 0.79,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 82.932,
#     'end': 83.012,
#     'score': 0.918,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moto?',
#     'start': 83.052,
#     'end': 83.332,
#     'score': 0.823,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 83.352,
#   'end': 85.232,
#   'text': 'Yo estoy en Río Negro.',
#   'words': [{'word': 'Yo',
#     'start': 83.352,
#     'end': 84.192,
#     'score': 0.913,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'estoy',
#     'start': 84.292,
#     'end': 84.712,
#     'score': 0.622,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'en',
#     'start': 84.812,
#     'end': 84.852,
#     'score': 0.107,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'Río',
#     'start': 84.872,
#     'end': 84.972,
#     'score': 0.211,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'Negro.',
#     'start': 85.012,
#     'end': 85.232,
#     'score': 0.394,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 101.132,
#   'end': 101.432,
#   'text': ' ¿Listo?',
#   'words': [{'word': '¿Listo?',
#     'start': 101.132,
#     'end': 101.432,
#     'score': 0.056,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 101.452,
#   'end': 104.493,
#   'text': 'Tengo segura modelo 2021 Suzuki TR150.',
#   'words': [{'word': 'Tengo',
#     'start': 101.452,
#     'end': 101.612,
#     'score': 0.309,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'segura',
#     'start': 101.632,
#     'end': 101.952,
#     'score': 0.335,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'modelo',
#     'start': 101.972,
#     'end': 102.472,
#     'score': 0.472,
#     'speaker': 'SPEAKER_01'},
#    {'word': '2021'},
#    {'word': 'Suzuki',
#     'start': 103.052,
#     'end': 104.093,
#     'score': 0.652,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'TR150.',
#     'start': 104.133,
#     'end': 104.493,
#     'score': 0.684,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 104.633,
#   'end': 105.473,
#   'text': '¿Está bien?',
#   'words': [{'word': '¿Está',
#     'start': 104.633,
#     'end': 104.813,
#     'score': 0.605,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'bien?',
#     'start': 104.873,
#     'end': 105.473,
#     'score': 0.77,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 105.713,
#   'end': 106.193,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 105.713,
#     'end': 106.193,
#     'score': 0.754,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 106.873,
#   'end': 107.113,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 106.873,
#     'end': 107.113,
#     'score': 0.72,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 107.593,
#   'end': 111.514,
#   'text': 'Entonces, mira, seguro sobre segura tu moto en un valor de $7,200,000.',
#   'words': [{'word': 'Entonces,',
#     'start': 107.593,
#     'end': 107.953,
#     'score': 0.821,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'mira,',
#     'start': 107.993,
#     'end': 108.133,
#     'score': 0.559,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'seguro',
#     'start': 108.253,
#     'end': 108.534,
#     'score': 0.744,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sobre',
#     'start': 108.554,
#     'end': 108.754,
#     'score': 0.617,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'segura',
#     'start': 108.794,
#     'end': 109.074,
#     'score': 0.728,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 109.134,
#     'end': 109.314,
#     'score': 0.885,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moto',
#     'start': 109.574,
#     'end': 109.874,
#     'score': 0.891,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 110.054,
#     'end': 110.154,
#     'score': 0.99,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 110.294,
#     'end': 110.374,
#     'score': 0.996,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'valor',
#     'start': 110.454,
#     'end': 110.854,
#     'score': 0.855,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 110.934,
#     'end': 111.514,
#     'score': 0.626,
#     'speaker': 'SPEAKER_01'},
#    {'word': '$7,200,000.'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 113.615,
#   'end': 115.515,
#   'text': '¿Qué te va a pedir la póliza con nosotros?',
#   'words': [{'word': '¿Qué',
#     'start': 113.615,
#     'end': 113.715,
#     'score': 0.856,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 113.775,
#     'end': 113.875,
#     'score': 0.75,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'va',
#     'start': 113.895,
#     'end': 113.975,
#     'score': 0.673,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 113.995,
#     'end': 114.015,
#     'score': 0.158,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pedir',
#     'start': 114.115,
#     'end': 114.375,
#     'score': 0.774,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 114.435,
#     'end': 114.495,
#     'score': 0.898,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'póliza',
#     'start': 114.555,
#     'end': 114.875,
#     'score': 0.769,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 114.935,
#     'end': 115.035,
#     'score': 0.75,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'nosotros?',
#     'start': 115.095,
#     'end': 115.515,
#     'score': 0.74,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 115.755,
#   'end': 121.916,
#   'text': 'Una responsabilidad civil o unos daños a terceros por un valor de $840,000,000 de pesos para cada evento.',
#   'words': [{'word': 'Una',
#     'start': 115.755,
#     'end': 115.875,
#     'score': 0.909,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'responsabilidad',
#     'start': 115.975,
#     'end': 116.715,
#     'score': 0.711,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'civil',
#     'start': 116.735,
#     'end': 117.115,
#     'score': 0.571,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'o',
#     'start': 117.255,
#     'end': 117.295,
#     'score': 0.873,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'unos',
#     'start': 117.375,
#     'end': 117.575,
#     'score': 0.796,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'daños',
#     'start': 117.635,
#     'end': 117.855,
#     'score': 0.877,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 117.935,
#     'end': 117.955,
#     'score': 0.953,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'terceros',
#     'start': 118.015,
#     'end': 118.476,
#     'score': 0.709,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'por',
#     'start': 118.576,
#     'end': 118.696,
#     'score': 0.81,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 118.756,
#     'end': 118.816,
#     'score': 0.991,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'valor',
#     'start': 118.876,
#     'end': 119.116,
#     'score': 0.925,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 119.156,
#     'end': 120.576,
#     'score': 0.414,
#     'speaker': 'SPEAKER_01'},
#    {'word': '$840,000,000'},
#    {'word': 'de',
#     'start': 120.636,
#     'end': 120.696,
#     'score': 0.796,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pesos',
#     'start': 120.776,
#     'end': 121.056,
#     'score': 0.583,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'para',
#     'start': 121.156,
#     'end': 121.296,
#     'score': 0.939,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cada',
#     'start': 121.396,
#     'end': 121.656,
#     'score': 0.893,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'evento.',
#     'start': 121.696,
#     'end': 121.916,
#     'score': 0.425,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 122.696,
#   'end': 129.998,
#   'text': 'Esta cobertura es la más importante porque una persona hasta podría perder su patrimonio si digamos con su vehículo llega a causar daño a otra persona, un vehículo, un Audi,',
#   'words': [{'word': 'Esta',
#     'start': 122.696,
#     'end': 122.836,
#     'score': 0.816,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cobertura',
#     'start': 122.896,
#     'end': 123.237,
#     'score': 0.833,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'es',
#     'start': 123.257,
#     'end': 123.317,
#     'score': 0.437,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 123.357,
#     'end': 123.437,
#     'score': 0.869,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'más',
#     'start': 123.477,
#     'end': 123.637,
#     'score': 0.461,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'importante',
#     'start': 123.677,
#     'end': 124.097,
#     'score': 0.899,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'porque',
#     'start': 124.157,
#     'end': 124.337,
#     'score': 0.841,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'una',
#     'start': 124.357,
#     'end': 124.437,
#     'score': 0.465,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'persona',
#     'start': 124.497,
#     'end': 124.817,
#     'score': 0.556,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hasta',
#     'start': 124.837,
#     'end': 124.957,
#     'score': 0.329,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'podría',
#     'start': 124.977,
#     'end': 125.197,
#     'score': 0.794,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'perder',
#     'start': 125.277,
#     'end': 125.577,
#     'score': 0.938,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'su',
#     'start': 125.637,
#     'end': 125.757,
#     'score': 0.67,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'patrimonio',
#     'start': 125.797,
#     'end': 126.297,
#     'score': 0.922,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'si',
#     'start': 126.317,
#     'end': 126.357,
#     'score': 0.005,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'digamos',
#     'start': 126.397,
#     'end': 126.757,
#     'score': 0.9,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 126.837,
#     'end': 126.957,
#     'score': 0.56,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'su',
#     'start': 126.977,
#     'end': 127.077,
#     'score': 0.666,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'vehículo',
#     'start': 127.097,
#     'end': 127.457,
#     'score': 0.78,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'llega',
#     'start': 127.497,
#     'end': 127.697,
#     'score': 0.884,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 127.717,
#     'end': 127.737,
#     'score': 0.146,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'causar',
#     'start': 127.777,
#     'end': 128.198,
#     'score': 0.799,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'daño',
#     'start': 128.258,
#     'end': 128.478,
#     'score': 0.842,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 128.498,
#     'end': 128.518,
#     'score': 0.044,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'otra',
#     'start': 128.558,
#     'end': 128.718,
#     'score': 0.417,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'persona,',
#     'start': 128.758,
#     'end': 129.058,
#     'score': 0.721,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 129.118,
#     'end': 129.178,
#     'score': 0.98,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'vehículo,',
#     'start': 129.198,
#     'end': 129.618,
#     'score': 0.794,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 129.638,
#     'end': 129.718,
#     'score': 0.781,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Audi,',
#     'start': 129.758,
#     'end': 129.998,
#     'score': 0.929,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 131.042,
#   'end': 138.844,
#   'text': ' En cambio, con una póliza como esta, le entregarías esa residencia a la aseguradora y no tendrías que pagar ningún deducible.',
#   'words': [{'word': 'En',
#     'start': 131.042,
#     'end': 131.122,
#     'score': 0.136,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cambio,',
#     'start': 131.142,
#     'end': 131.262,
#     'score': 0.03,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 131.282,
#     'end': 131.342,
#     'score': 0.061,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'una',
#     'start': 131.362,
#     'end': 131.422,
#     'score': 0.066,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'póliza',
#     'start': 131.442,
#     'end': 131.562,
#     'score': 0.036,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'como',
#     'start': 131.582,
#     'end': 131.662,
#     'score': 0.116,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'esta,',
#     'start': 131.762,
#     'end': 131.942,
#     'score': 0.696,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'le',
#     'start': 132.002,
#     'end': 132.142,
#     'score': 0.57,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'entregarías',
#     'start': 132.282,
#     'end': 133.483,
#     'score': 0.569,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'esa',
#     'start': 133.943,
#     'end': 134.123,
#     'score': 0.557,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'residencia',
#     'start': 134.223,
#     'end': 135.703,
#     'score': 0.745,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 135.723,
#     'end': 135.743,
#     'score': 0.012,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 135.763,
#     'end': 135.803,
#     'score': 0.536,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'aseguradora',
#     'start': 135.823,
#     'end': 136.443,
#     'score': 0.66,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y',
#     'start': 136.823,
#     'end': 136.863,
#     'score': 0.539,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'no',
#     'start': 136.903,
#     'end': 136.963,
#     'score': 0.992,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tendrías',
#     'start': 137.043,
#     'end': 137.403,
#     'score': 0.772,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 137.443,
#     'end': 137.543,
#     'score': 0.837,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pagar',
#     'start': 137.623,
#     'end': 137.864,
#     'score': 0.909,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ningún',
#     'start': 137.964,
#     'end': 138.224,
#     'score': 0.988,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'deducible.',
#     'start': 138.264,
#     'end': 138.844,
#     'score': 0.739,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 139.364,
#   'end': 151.687,
#   'text': 'Si en alguno de estos casos requieres o solicitas de un abogado, Sura tiene su propio bufet de abogados que te acompañaría en cada caso y tampoco tendrías que pagar nada adicional.',
#   'words': [{'word': 'Si',
#     'start': 139.364,
#     'end': 139.424,
#     'score': 0.596,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 139.444,
#     'end': 139.524,
#     'score': 0.657,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'alguno',
#     'start': 139.564,
#     'end': 139.824,
#     'score': 0.481,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'de',
#     'start': 139.844,
#     'end': 139.924,
#     'score': 0.466,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'estos',
#     'start': 139.944,
#     'end': 140.124,
#     'score': 0.433,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'casos',
#     'start': 140.204,
#     'end': 140.544,
#     'score': 0.707,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'requieres',
#     'start': 140.604,
#     'end': 141.064,
#     'score': 0.81,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'o',
#     'start': 141.184,
#     'end': 141.224,
#     'score': 0.651,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'solicitas',
#     'start': 141.244,
#     'end': 141.644,
#     'score': 0.641,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 141.664,
#     'end': 141.724,
#     'score': 0.842,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 141.764,
#     'end': 141.844,
#     'score': 0.822,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'abogado,',
#     'start': 141.864,
#     'end': 142.164,
#     'score': 0.561,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Sura',
#     'start': 142.365,
#     'end': 142.625,
#     'score': 0.782,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tiene',
#     'start': 142.665,
#     'end': 142.825,
#     'score': 0.776,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'su',
#     'start': 142.885,
#     'end': 142.965,
#     'score': 0.851,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'propio',
#     'start': 143.025,
#     'end': 143.325,
#     'score': 0.522,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'bufet',
#     'start': 143.345,
#     'end': 143.565,
#     'score': 0.527,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 143.585,
#     'end': 143.645,
#     'score': 0.504,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'abogados',
#     'start': 143.685,
#     'end': 143.925,
#     'score': 0.323,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 144.005,
#     'end': 144.085,
#     'score': 0.22,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 144.105,
#     'end': 144.185,
#     'score': 0.595,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'acompañaría',
#     'start': 144.205,
#     'end': 144.785,
#     'score': 0.698,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 144.805,
#     'end': 144.845,
#     'score': 0.006,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cada',
#     'start': 144.925,
#     'end': 145.065,
#     'score': 0.477,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'caso',
#     'start': 145.185,
#     'end': 145.465,
#     'score': 0.64,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y',
#     'start': 145.805,
#     'end': 145.865,
#     'score': 0.758,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tampoco',
#     'start': 145.925,
#     'end': 146.225,
#     'score': 0.741,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tendrías',
#     'start': 146.305,
#     'end': 146.605,
#     'score': 0.43,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 146.665,
#     'end': 146.805,
#     'score': 0.335,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pagar',
#     'start': 146.845,
#     'end': 150.846,
#     'score': 0.633,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'nada',
#     'start': 150.886,
#     'end': 151.066,
#     'score': 0.424,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'adicional.',
#     'start': 151.106,
#     'end': 151.687,
#     'score': 0.455,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 152.127,
#   'end': 158.128,
#   'text': 'Si tu moto llega a tener algún choque y pierde más del 75% esto quiere decir una pérdida total',
#   'words': [{'word': 'Si',
#     'start': 152.127,
#     'end': 152.207,
#     'score': 0.71,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 152.227,
#     'end': 152.367,
#     'score': 0.641,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moto',
#     'start': 152.407,
#     'end': 152.627,
#     'score': 0.928,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'llega',
#     'start': 152.667,
#     'end': 152.847,
#     'score': 0.821,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 152.867,
#     'end': 152.887,
#     'score': 0.733,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tener',
#     'start': 152.927,
#     'end': 153.147,
#     'score': 0.771,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'algún',
#     'start': 153.187,
#     'end': 153.427,
#     'score': 0.892,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'choque',
#     'start': 153.487,
#     'end': 153.787,
#     'score': 0.803,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y',
#     'start': 153.847,
#     'end': 153.887,
#     'score': 0.551,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pierde',
#     'start': 153.947,
#     'end': 154.247,
#     'score': 0.732,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'más',
#     'start': 154.287,
#     'end': 154.387,
#     'score': 0.441,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'del',
#     'start': 154.427,
#     'end': 154.787,
#     'score': 0.694,
#     'speaker': 'SPEAKER_01'},
#    {'word': '75%'},
#    {'word': 'esto',
#     'start': 154.947,
#     'end': 155.167,
#     'score': 0.563,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'quiere',
#     'start': 156.768,
#     'end': 156.928,
#     'score': 0.817,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'decir',
#     'start': 156.948,
#     'end': 157.128,
#     'score': 0.589,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'una',
#     'start': 157.208,
#     'end': 157.288,
#     'score': 0.989,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'pérdida',
#     'start': 157.388,
#     'end': 157.748,
#     'score': 0.92,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'total',
#     'start': 157.828,
#     'end': 158.128,
#     'score': 0.999,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 158.655,
#   'end': 162.316,
#   'text': ' Seguro Sura te lo cubre al 80% del valor comercial de tu moto.',
#   'words': [{'word': 'Seguro',
#     'start': 158.655,
#     'end': 159.015,
#     'score': 0.641,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Sura',
#     'start': 159.035,
#     'end': 159.195,
#     'score': 0.598,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 159.255,
#     'end': 159.315,
#     'score': 0.587,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'lo',
#     'start': 159.375,
#     'end': 159.475,
#     'score': 0.822,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'cubre',
#     'start': 159.535,
#     'end': 159.715,
#     'score': 0.674,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'al',
#     'start': 159.755,
#     'end': 159.835,
#     'score': 0.23,
#     'speaker': 'SPEAKER_01'},
#    {'word': '80%'},
#    {'word': 'del',
#     'start': 160.816,
#     'end': 160.936,
#     'score': 0.698,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'valor',
#     'start': 160.976,
#     'end': 161.196,
#     'score': 0.876,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'comercial',
#     'start': 161.276,
#     'end': 161.716,
#     'score': 0.823,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 161.776,
#     'end': 161.836,
#     'score': 0.77,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 161.936,
#     'end': 162.076,
#     'score': 0.834,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'moto.',
#     'start': 162.096,
#     'end': 162.316,
#     'score': 0.551,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 162.996,
#   'end': 163.376,
#   'text': 'Sí.',
#   'words': [{'word': 'Sí.',
#     'start': 162.996,
#     'end': 163.376,
#     'score': 0.7,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 163.436,
#   'end': 164.236,
#   'text': 'Frente al hurto.',
#   'words': [{'word': 'Frente',
#     'start': 163.436,
#     'end': 163.716,
#     'score': 0.833,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'al',
#     'start': 163.756,
#     'end': 163.816,
#     'score': 0.586,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hurto.',
#     'start': 163.856,
#     'end': 164.236,
#     'score': 0.813,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 164.517,
#   'end': 173.139,
#   'text': 'Si te lo llegan a hurtar, sea que por un hurto simple o un hurto agravado, el hurto simple es que las has ahogado en tu casa y te la robaron, y el hurto agravado es que te la lleguen a robar con algún arma.',
#   'words': [{'word': 'Si',
#     'start': 164.517,
#     'end': 164.597,
#     'score': 0.581,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 164.637,
#     'end': 164.737,
#     'score': 0.525,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'lo',
#     'start': 164.777,
#     'end': 164.837,
#     'score': 0.636,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'llegan',
#     'start': 164.877,
#     'end': 165.157,
#     'score': 0.795,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 165.177,
#     'end': 165.197,
#     'score': 0.819,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hurtar,',
#     'start': 165.237,
#     'end': 165.637,
#     'score': 0.706,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sea',
#     'start': 165.657,
#     'end': 165.817,
#     'score': 0.657,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 165.877,
#     'end': 166.057,
#     'score': 0.447,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'por',
#     'start': 166.117,
#     'end': 166.177,
#     'score': 0.418,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 166.217,
#     'end': 166.317,
#     'score': 0.612,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hurto',
#     'start': 166.337,
#     'end': 166.597,
#     'score': 0.505,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'simple',
#     'start': 166.657,
#     'end': 167.037,
#     'score': 0.698,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'o',
#     'start': 167.057,
#     'end': 167.077,
#     'score': 0.015,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 167.117,
#     'end': 167.157,
#     'score': 0.952,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hurto',
#     'start': 167.197,
#     'end': 167.417,
#     'score': 0.762,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'agravado,',
#     'start': 167.437,
#     'end': 167.937,
#     'score': 0.804,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'el',
#     'start': 167.957,
#     'end': 167.997,
#     'score': 0.002,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hurto',
#     'start': 168.197,
#     'end': 168.398,
#     'score': 0.677,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'simple',
#     'start': 168.418,
#     'end': 168.618,
#     'score': 0.603,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'es',
#     'start': 168.638,
#     'end': 168.678,
#     'score': 0.001,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 168.698,
#     'end': 168.778,
#     'score': 0.644,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'las',
#     'start': 168.818,
#     'end': 168.878,
#     'score': 0.645,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'has',
#     'start': 168.898,
#     'end': 168.978,
#     'score': 0.435,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ahogado',
#     'start': 168.998,
#     'end': 169.218,
#     'score': 0.199,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 169.258,
#     'end': 169.298,
#     'score': 0.012,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tu',
#     'start': 169.338,
#     'end': 169.418,
#     'score': 0.845,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'casa',
#     'start': 169.458,
#     'end': 169.658,
#     'score': 0.554,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y',
#     'start': 169.678,
#     'end': 169.698,
#     'score': 0.972,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 169.738,
#     'end': 169.818,
#     'score': 0.672,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 169.878,
#     'end': 169.958,
#     'score': 0.871,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'robaron,',
#     'start': 170.038,
#     'end': 170.398,
#     'score': 0.822,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y',
#     'start': 170.838,
#     'end': 170.878,
#     'score': 0.958,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'el',
#     'start': 170.918,
#     'end': 170.978,
#     'score': 0.921,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hurto',
#     'start': 170.998,
#     'end': 171.198,
#     'score': 0.413,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'agravado',
#     'start': 171.218,
#     'end': 171.478,
#     'score': 0.639,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'es',
#     'start': 171.498,
#     'end': 171.538,
#     'score': 0.008,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 171.578,
#     'end': 171.658,
#     'score': 0.841,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 171.698,
#     'end': 171.798,
#     'score': 0.656,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 171.818,
#     'end': 171.878,
#     'score': 0.808,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'lleguen',
#     'start': 171.898,
#     'end': 172.178,
#     'score': 0.807,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'a',
#     'start': 172.198,
#     'end': 172.219,
#     'score': 0.898,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'robar',
#     'start': 172.299,
#     'end': 172.499,
#     'score': 0.693,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 172.559,
#     'end': 172.679,
#     'score': 0.88,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'algún',
#     'start': 172.719,
#     'end': 172.959,
#     'score': 0.888,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'arma.',
#     'start': 172.999,
#     'end': 173.139,
#     'score': 0.546,
# ...
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 560.483,
#     'end': 560.543,
#     'score': 0.709,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'envío',
#     'start': 560.563,
#     'end': 560.783,
#     'score': 0.726,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'el',
#     'start': 560.823,
#     'end': 560.863,
#     'score': 0.6,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'link',
#     'start': 560.903,
#     'end': 561.083,
#     'score': 0.724,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'para',
#     'start': 561.143,
#     'end': 561.323,
#     'score': 0.984,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'mañana.',
#     'start': 561.383,
#     'end': 561.804,
#     'score': 0.884,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 562.544,
#   'end': 565.868,
#   'text': 'Para mañana ese link te serviría entre 9 y 5 de la tarde.',
#   'words': [{'word': 'Para',
#     'start': 562.544,
#     'end': 562.685,
#     'score': 0.441,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'mañana',
#     'start': 562.705,
#     'end': 562.965,
#     'score': 0.511,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'ese',
#     'start': 562.985,
#     'end': 563.185,
#     'score': 0.413,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'link',
#     'start': 563.245,
#     'end': 563.485,
#     'score': 0.707,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 563.605,
#     'end': 564.066,
#     'score': 0.749,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'serviría',
#     'start': 564.086,
#     'end': 564.666,
#     'score': 0.836,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'entre',
#     'start': 564.927,
#     'end': 565.167,
#     'score': 0.871,
#     'speaker': 'SPEAKER_01'},
#    {'word': '9'},
#    {'word': 'y',
#     'start': 565.207,
#     'end': 565.227,
#     'score': 0.001,
#     'speaker': 'SPEAKER_01'},
#    {'word': '5'},
#    {'word': 'de',
#     'start': 565.367,
#     'end': 565.587,
#     'score': 0.7,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 565.627,
#     'end': 565.687,
#     'score': 0.243,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'tarde.',
#     'start': 565.727,
#     'end': 565.868,
#     'score': 0.148,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 569.235,
#   'end': 572.197,
#   'text': ' O sea, si te da para ingresarlo, puedes hacerlo el día de mañana.',
#   'words': [{'word': 'O',
#     'start': 569.235,
#     'end': 569.295,
#     'score': 0.43,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'sea,',
#     'start': 569.375,
#     'end': 569.535,
#     'score': 0.324,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'si',
#     'start': 569.595,
#     'end': 569.655,
#     'score': 0.134,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'te',
#     'start': 569.695,
#     'end': 569.775,
#     'score': 0.234,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'da',
#     'start': 569.795,
#     'end': 569.976,
#     'score': 0.528,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'para',
#     'start': 569.996,
#     'end': 570.116,
#     'score': 0.573,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ingresarlo,',
#     'start': 570.136,
#     'end': 570.556,
#     'score': 0.81,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'puedes',
#     'start': 570.956,
#     'end': 571.116,
#     'score': 0.577,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hacerlo',
#     'start': 571.136,
#     'end': 571.417,
#     'score': 0.429,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'el',
#     'start': 571.437,
#     'end': 571.537,
#     'score': 0.692,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'día',
#     'start': 571.557,
#     'end': 571.717,
#     'score': 0.717,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 571.737,
#     'end': 571.777,
#     'score': 0.002,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'mañana.',
#     'start': 571.857,
#     'end': 572.197,
#     'score': 0.811,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 572.277,
#   'end': 572.978,
#   'text': 'Pero es muy importante.',
#   'words': [{'word': 'Pero',
#     'start': 572.277,
#     'end': 572.377,
#     'score': 0.718,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'es',
#     'start': 572.417,
#     'end': 572.477,
#     'score': 0.744,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'muy',
#     'start': 572.497,
#     'end': 572.578,
#     'score': 0.803,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'importante.',
#     'start': 572.618,
#     'end': 572.978,
#     'score': 0.914,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 573.498,
#   'end': 577.001,
#   'text': 'Si te da para ingresarlo, al momento que lo abras, termine la inspección.',
#   'words': [{'word': 'Si',
#     'start': 573.498,
#     'end': 573.899,
#     'score': 0.645,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 573.919,
#     'end': 573.999,
#     'score': 0.474,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'da',
#     'start': 574.019,
#     'end': 574.079,
#     'score': 0.373,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'para',
#     'start': 574.099,
#     'end': 574.199,
#     'score': 0.682,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ingresarlo,',
#     'start': 574.219,
#     'end': 574.519,
#     'score': 0.48,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'al',
#     'start': 574.979,
#     'end': 575.059,
#     'score': 0.562,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'momento',
#     'start': 575.099,
#     'end': 575.36,
#     'score': 0.759,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 575.4,
#     'end': 575.48,
#     'score': 0.838,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'lo',
#     'start': 575.52,
#     'end': 575.58,
#     'score': 0.75,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'abras,',
#     'start': 575.62,
#     'end': 575.84,
#     'score': 0.603,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'termine',
#     'start': 575.92,
#     'end': 576.34,
#     'score': 0.771,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 576.38,
#     'end': 576.42,
#     'score': 0.977,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'inspección.',
#     'start': 576.46,
#     'end': 577.001,
#     'score': 0.853,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 577.061,
#   'end': 580.283,
#   'text': 'Porque no se puede, digamos, abrir y, ah, vuelvo otra vez en un momentico.',
#   'words': [{'word': 'Porque',
#     'start': 577.061,
#     'end': 577.221,
#     'score': 0.928,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'no',
#     'start': 577.261,
#     'end': 577.341,
#     'score': 0.53,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'se',
#     'start': 577.361,
#     'end': 577.441,
#     'score': 0.542,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'puede,',
#     'start': 577.481,
#     'end': 577.641,
#     'score': 0.669,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'digamos,',
#     'start': 577.681,
#     'end': 577.982,
#     'score': 0.755,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'abrir',
#     'start': 578.022,
#     'end': 578.242,
#     'score': 0.815,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y,',
#     'start': 578.262,
#     'end': 578.362,
#     'score': 0.771,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'ah,',
#     'start': 578.462,
#     'end': 578.622,
#     'score': 0.654,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'vuelvo',
#     'start': 578.822,
#     'end': 579.062,
#     'score': 0.623,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'otra',
#     'start': 579.102,
#     'end': 579.242,
#     'score': 0.768,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'vez',
#     'start': 579.283,
#     'end': 579.363,
#     'score': 0.95,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 579.383,
#     'end': 579.423,
#     'score': 0.032,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'un',
#     'start': 579.623,
#     'end': 579.703,
#     'score': 0.691,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'momentico.',
#     'start': 579.823,
#     'end': 580.283,
#     'score': 0.893,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 580.303,
#   'end': 580.904,
#   'text': 'No, no se puede.',
#   'words': [{'word': 'No,',
#     'start': 580.303,
#     'end': 580.403,
#     'score': 0.806,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'no',
#     'start': 580.443,
#     'end': 580.523,
#     'score': 0.75,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'se',
#     'start': 580.543,
#     'end': 580.624,
#     'score': 0.421,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'puede.',
#     'start': 580.664,
#     'end': 580.904,
#     'score': 0.695,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 580.984,
#   'end': 583.426,
#   'text': 'Es de iniciar y terminar por completo la inspección.',
#   'words': [{'word': 'Es',
#     'start': 580.984,
#     'end': 581.044,
#     'score': 0.613,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 581.064,
#     'end': 581.164,
#     'score': 0.72,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'iniciar',
#     'start': 581.544,
#     'end': 581.804,
#     'score': 0.898,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'y',
#     'start': 581.864,
#     'end': 581.884,
#     'score': 0.782,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'terminar',
#     'start': 581.944,
#     'end': 582.285,
#     'score': 0.933,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'por',
#     'start': 582.345,
#     'end': 582.445,
#     'score': 0.843,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'completo',
#     'start': 582.505,
#     'end': 582.825,
#     'score': 0.878,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 582.885,
#     'end': 582.925,
#     'score': 0.954,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'inspección.',
#     'start': 582.965,
#     'end': 583.426,
#     'score': 0.793,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 583.626,
#   'end': 585.147,
#   'text': 'Listo.',
#   'words': [{'word': 'Listo.',
#     'start': 583.626,
#     'end': 585.147,
#     'score': 0.755,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 585.167,
#   'end': 585.507,
#   'text': 'Listo.',
#   'words': [{'word': 'Listo.',
#     'start': 585.167,
#     'end': 585.507,
#     'score': 0.394,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 585.587,
#   'end': 589.39,
#   'text': 'Y, Lino, yo ya me comunicaría entonces contigo el lunes para que podamos reagendarla.',
#   'words': [{'word': 'Y,',
#     'start': 585.587,
#     'end': 585.627,
#     'score': 0.418,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'Lino,',
#     'start': 585.647,
#     'end': 585.827,
#     'score': 0.372,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'yo',
#     'start': 585.867,
#     'end': 585.927,
#     'score': 0.254,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'ya',
#     'start': 585.967,
#     'end': 586.108,
#     'score': 0.625,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'me',
#     'start': 586.128,
#     'end': 586.228,
#     'score': 0.359,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'comunicaría',
#     'start': 586.268,
#     'end': 586.708,
#     'score': 0.833,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'entonces',
#     'start': 586.748,
#     'end': 587.088,
#     'score': 0.481,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'contigo',
#     'start': 587.108,
#     'end': 587.449,
#     'score': 0.624,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'el',
#     'start': 587.469,
#     'end': 587.509,
#     'score': 0.34,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'lunes',
#     'start': 587.529,
#     'end': 587.769,
#     'score': 0.683,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'para',
#     'start': 587.829,
#     'end': 587.949,
#     'score': 0.976,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 588.369,
#     'end': 588.449,
#     'score': 0.303,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'podamos',
#     'start': 588.489,
#     'end': 588.75,
#     'score': 0.671,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'reagendarla.',
#     'start': 588.85,
#     'end': 589.39,
#     'score': 0.73,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 589.41,
#   'end': 591.091,
#   'text': 'Pero igual te la damos en la inspección para mañana.',
#   'words': [{'word': 'Pero',
#     'start': 589.41,
#     'end': 589.51,
#     'score': 0.459,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'igual',
#     'start': 589.55,
#     'end': 589.67,
#     'score': 0.747,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'te',
#     'start': 589.69,
#     'end': 589.77,
#     'score': 0.499,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'la',
#     'start': 589.79,
#     'end': 589.83,
#     'score': 0.516,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'damos',
#     'start': 589.87,
#     'end': 590.051,
#     'score': 0.461,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'en',
#     'start': 590.111,
#     'end': 590.151,
#     'score': 0.426,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'la',
#     'start': 590.171,
#     'end': 590.211,
#     'score': 0.007,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'inspección',
#     'start': 590.231,
#     'end': 590.571,
#     'score': 0.202,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'para',
#     'start': 590.591,
#     'end': 590.751,
#     'score': 0.872,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'mañana.',
#     'start': 590.791,
#     'end': 591.091,
#     'score': 0.976,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 592.552,
#   'end': 592.853,
#   'text': 'Listo.',
#   'words': [{'word': 'Listo.',
#     'start': 592.552,
#     'end': 592.853,
#     'score': 0.558,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 592.873,
#   'end': 593.073,
#   'text': 'Bueno.',
#   'words': [{'word': 'Bueno.',
#     'start': 592.873,
#     'end': 593.073,
#     'score': 0.287,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 593.113,
#   'end': 594.494,
#   'text': 'Listo, hágale fuerza.',
#   'words': [{'word': 'Listo,',
#     'start': 593.113,
#     'end': 594.053,
#     'score': 0.509,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'hágale',
#     'start': 594.073,
#     'end': 594.254,
#     'score': 0.236,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'fuerza.',
#     'start': 594.274,
#     'end': 594.494,
#     'score': 0.23,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 594.514,
#   'end': 596.896,
#   'text': 'Bueno, Juan, ¿te recuerda que hablaste con Juliana Jaramillo de Segurosura?',
#   'words': [{'word': 'Bueno,',
#     'start': 594.514,
#     'end': 594.694,
#     'score': 0.321,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Juan,',
#     'start': 594.734,
#     'end': 594.814,
#     'score': 0.158,
#     'speaker': 'SPEAKER_01'},
#    {'word': '¿te',
#     'start': 594.834,
#     'end': 594.914,
#     'score': 0.404,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'recuerda',
#     'start': 594.954,
#     'end': 595.214,
#     'score': 0.668,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'que',
#     'start': 595.234,
#     'end': 595.294,
#     'score': 0.707,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hablaste',
#     'start': 595.314,
#     'end': 595.575,
#     'score': 0.477,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'con',
#     'start': 595.595,
#     'end': 595.675,
#     'score': 0.443,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Juliana',
#     'start': 595.695,
#     'end': 595.935,
#     'score': 0.496,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Jaramillo',
#     'start': 595.955,
#     'end': 596.255,
#     'score': 0.503,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'de',
#     'start': 596.275,
#     'end': 596.335,
#     'score': 0.033,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'Segurosura?',
#     'start': 596.355,
#     'end': 596.896,
#     'score': 0.612,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'},
#  {'start': 598.177,
#   'end': 598.617,
#   'text': 'Listo, gracias.',
#   'words': [{'word': 'Listo,',
#     'start': 598.177,
#     'end': 598.377,
#     'score': 0.312,
#     'speaker': 'SPEAKER_00'},
#    {'word': 'gracias.',
#     'start': 598.397,
#     'end': 598.617,
#     'score': 0.183,
#     'speaker': 'SPEAKER_00'}],
#   'speaker': 'SPEAKER_00'},
#  {'start': 599.019,
#   'end': 599.882,
#   'text': ' Y bueno, hasta luego.',
#   'words': [{'word': 'Y',
#     'start': 599.019,
#     'end': 599.204,
#     'score': 0.441,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'bueno,',
#     'start': 599.224,
#     'end': 599.43,
#     'score': 0.193,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'hasta',
#     'start': 599.45,
#     'end': 599.635,
#     'score': 0.422,
#     'speaker': 'SPEAKER_01'},
#    {'word': 'luego.',
#     'start': 599.656,
#     'end': 599.882,
#     'score': 0.467,
#     'speaker': 'SPEAKER_01'}],
#   'speaker': 'SPEAKER_01'}]

# %%
# Dataframe de diarizacion
diarizacion = pd.DataFrame(result['segments'])

# Dataframe con el texto y el respectivo score promedio
transcription_df = pd.concat([diarizacion, scores], axis = 1)
transcription_df
# Out:
#        start      end                                               text  \
# 0     10.742   10.922                                              Hola.
# 1     11.042   13.244                                 Sí, buenas tardes.
# 2     13.264   14.105                            Sí, con Juan Cartagena.
# 3     17.988   18.248                                                Sí.
# 4     18.388   18.608                                              Hola.
# ..       ...      ...                                                ...
# 165  592.873  593.073                                             Bueno.
# 166  593.113  594.494                              Listo, hágale fuerza.
# 167  594.514  596.896  Bueno, Juan, ¿te recuerda que hablaste con Jul...
# 168  598.177  598.617                                    Listo, gracias.
# 169  599.019  599.882                              Y bueno, hasta luego.
#
#                                                  words     speaker  avg_score
# 0    [{'word': 'Hola.', 'start': 10.742, 'end': 10....  SPEAKER_00   0.289000
# 1    [{'word': 'Sí,', 'start': 11.042, 'end': 12.10...  SPEAKER_01   0.495000
# 2    [{'word': 'Sí,', 'start': 13.264, 'end': 13.30...  SPEAKER_01   0.347750
# 3    [{'word': 'Sí.', 'start': 17.988, 'end': 18.24...  SPEAKER_01   0.217000
# 4    [{'word': 'Hola.', 'start': 18.388, 'end': 18....  SPEAKER_01   0.533000
# ..                                                 ...         ...        ...
# 165  [{'word': 'Bueno.', 'start': 592.873, 'end': 5...  SPEAKER_00   0.287000
# 166  [{'word': 'Listo,', 'start': 593.113, 'end': 5...  SPEAKER_00   0.325000
# 167  [{'word': 'Bueno,', 'start': 594.514, 'end': 5...  SPEAKER_01   0.438364
# 168  [{'word': 'Listo,', 'start': 598.177, 'end': 5...  SPEAKER_00   0.247500
# 169  [{'word': 'Y', 'start': 599.019, 'end': 599.20...  SPEAKER_01   0.380750
#
# [170 rows x 6 columns]

# %%
# Timestamps
from operator import itemgetter
aux_iter = 0
for segment in result["segments"]:
    if "speaker" in segment:
        aux_info = itemgetter("start", "end", "text", "speaker")(segment)
        print(f"[{aux_info[0]} - {aux_info[1]}]  [{aux_info[3]}] [Score - {round(transcription_df['avg_score'][aux_iter], 4)}]: {aux_info[2]}")
    else:
        aux_info = itemgetter("start", "end", "text")(segment)
        print(f"[{aux_info[0]} - {aux_info[1]}] [Score - {round(transcription_df['avg_score'][aux_iter], 4)}]: {aux_info[2]}") 
    aux_iter += 1
print(f"Average score: {round(transcription_df.avg_score.mean(), 4)}, missing speakers: {transcription_df['speaker'].isna().sum()}, missing scores: {transcription_df['avg_score'].isna().sum()}")
# Out:
# [10.742 - 10.922]  [SPEAKER_00] [Score - 0.289]:  Hola.
# [11.042 - 13.244]  [SPEAKER_01] [Score - 0.495]: Sí, buenas tardes.
# [13.264 - 14.105]  [SPEAKER_01] [Score - 0.3478]: Sí, con Juan Cartagena.
# [17.988 - 18.248]  [SPEAKER_01] [Score - 0.217]: Sí.
# [18.388 - 18.608]  [SPEAKER_01] [Score - 0.533]: Hola.
# [18.628 - 18.808]  [SPEAKER_01] [Score - 0.582]: Hola.
# [18.848 - 19.369]  [SPEAKER_01] [Score - 0.511]: ¿Cómo estás?
# [20.329 - 22.191]  [SPEAKER_00] [Score - 0.3275]: Muy bien.
# [22.231 - 22.831]  [SPEAKER_01] [Score - 0.539]: Ay, qué bueno.
# [22.871 - 23.512]  [SPEAKER_01] [Score - 0.7635]: Me alegro.
# [24.012 - 30.357]  [SPEAKER_01] [Score - 0.6444]: Juan, vimos en nuestro sistema tu interés por asegurar tu moto con la policía a todo riesgo, con placas RKQ33F.
# [30.537 - 31.898]  [SPEAKER_01] [Score - 0.885]: ¿Es correcto?
# [32.599 - 34.02]  [SPEAKER_00] [Score - 0.756]: Sí.
# [34.06 - 34.4]  [SPEAKER_01] [Score - 0.582]: Listo, Juan.
# [34.44 - 36.502]  [SPEAKER_01] [Score - 0.5882]: Y cuando ingresaste al sistema, ¿pudiste ver los valores?
# [541.139 - 542.7]  [SPEAKER_01] [Score - 0.3373]: Ah, listo, listo.
# [542.72 - 546.301]  [SPEAKER_00] [Score - 0.461]: Muchas gracias.
# [547.242 - 549.363]  [SPEAKER_01] [Score - 0.5294]: Entonces, ¿te da agenda la inspección para qué?
# [551.334 - 554.697]  [SPEAKER_00] [Score - 0.2893]:  No sé cómo explicar, no sé que ella tenga disponible.
# [555.338 - 561.804]  [SPEAKER_01] [Score - 0.5896]: O hagamos una cosa, yo te voy a mandar esa cotización que acabas de realizar a tu whatsapp y yo te envío el link para mañana.
# [562.544 - 565.868]  [SPEAKER_01] [Score - 0.5109]: Para mañana ese link te serviría entre 9 y 5 de la tarde.
# [569.235 - 572.197]  [SPEAKER_01] [Score - 0.4816]:  O sea, si te da para ingresarlo, puedes hacerlo el día de mañana.
# [572.277 - 572.978]  [SPEAKER_01] [Score - 0.7948]: Pero es muy importante.
# [573.498 - 577.001]  [SPEAKER_01] [Score - 0.6744]: Si te da para ingresarlo, al momento que lo abras, termine la inspección.
# [577.061 - 580.283]  [SPEAKER_01] [Score - 0.6872]: Porque no se puede, digamos, abrir y, ah, vuelvo otra vez en un momentico.
# [580.303 - 580.904]  [SPEAKER_01] [Score - 0.668]: No, no se puede.
# [580.984 - 583.426]  [SPEAKER_01] [Score - 0.8238]: Es de iniciar y terminar por completo la inspección.
# [583.626 - 585.147]  [SPEAKER_00] [Score - 0.755]: Listo.
# [585.167 - 585.507]  [SPEAKER_01] [Score - 0.394]: Listo.
# [585.587 - 589.39]  [SPEAKER_01] [Score - 0.5478]: Y, Lino, yo ya me comunicaría entonces contigo el lunes para que podamos reagendarla.
# [589.41 - 591.091]  [SPEAKER_01] [Score - 0.5165]: Pero igual te la damos en la inspección para mañana.
# [592.552 - 592.853]  [SPEAKER_00] [Score - 0.558]: Listo.
# [592.873 - 593.073]  [SPEAKER_00] [Score - 0.287]: Bueno.
# [593.113 - 594.494]  [SPEAKER_00] [Score - 0.325]: Listo, hágale fuerza.
# [594.514 - 596.896]  [SPEAKER_01] [Score - 0.4384]: Bueno, Juan, ¿te recuerda que hablaste con Juliana Jaramillo de Segurosura?
# [598.177 - 598.617]  [SPEAKER_00] [Score - 0.2475]: Listo, gracias.
# [599.019 - 599.882]  [SPEAKER_01] [Score - 0.3808]:  Y bueno, hasta luego.
# Average score: 0.5838, missing speakers: 3, missing scores: 3

# %% [markdown]
# # Generalización del ejercicio

# %%
# Lista de nombres de variables locales
# variables_locales = list(locals().keys())

# Eliminar objetos locales excepto las funciones y librerías importadas
# for nombre in variables_locales:
#    objeto = locals()[nombre]
#    if not callable(objeto) and not hasattr(objeto, '__module__'):
#        del locals()[nombre]

# %%
# Guardando ejercicio previo antes de liberar recursos
# Lista de objetos que deseas conservar
# objetos_a_conservar = ["transcription_df", "pd", "os", "gc", "whisper", "whisperx", "itemgetter"]

# Crear un diccionario de los objetos que deseas conservar
# objetos_conservados = {nombre: globals()[nombre] for nombre in objetos_a_conservar}

# Limpiar el entorno global
# for nombre in list(globals().keys()):
#    if nombre not in objetos_a_conservar:
#        del globals()[nombre]

# Actualizar el entorno global con los objetos conservados
# globals().update(objetos_conservados)

# %%
def transcription(audio_file, token, language = "es", num_speakers = 2, device = "cuda", batch_size = 16, compute_type = "float16"):
    """Argumentos
    audio_file :  Archivo que va a ser transcrito (incluyendo la extension).
    language: Idioma del audio.
    num_speakers: Numero de personas que hablan en el audio.
    token: HugginFace token
    """
    # INICIO FLUJO DE TRABAJO DE WHISPERX (EN GITHUB)
    import whisperx
    import gc 
    # ------------------------------------------------------------------------------------------
    # SE ESPECIFICA EN EL ARGUMENTO DE LA FUNCION
    # device = "cuda" 
    # audio_file = audio_file
    # batch_size = 16 # reduce if low on GPU mem
    # compute_type = "float16" # change to "int8" if low on GPU mem (may reduce accuracy)
    # ------------------------------------------------------------------------------------------

    # 1. Transcribe with original whisper (batched)
    model = whisperx.load_model("large-v2", device, compute_type = compute_type, language = language)

    # save model to local path (optional)
    # model_dir = "/path/"
    # model = whisperx.load_model("large-v2", device, compute_type=compute_type, download_root=model_dir)

    audio = whisperx.load_audio(audio_file)
    result = model.transcribe(audio, batch_size = batch_size, language = language)

    # delete model if low on GPU resources
    import gc; gc.collect(); torch.cuda.empty_cache(); del model

    # 2. Align whisper output
    model_a, metadata = whisperx.load_align_model(language_code = result["language"], device = device)
    result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments = False)

    # delete model if low on GPU resources
    import gc; gc.collect(); torch.cuda.empty_cache(); del model_a

    # 3. Assign speaker labels
    # AQUÍ SE DEBE COLOCAR EL TOKEN DE AUTENTICACIÓN GENERADO EN HUGGINGFACE
    diarize_model = whisperx.DiarizationPipeline(use_auth_token = token, device = device)

    # add min/max number of speakers if known
    diarize_segments = diarize_model(audio, num_speakers = num_speakers)
    # diarize_model(audio, min_speakers=min_speakers, max_speakers=max_speakers)

    result = whisperx.assign_word_speakers(diarize_segments, result)
    # FIN FLUJO DE TRABAJO DE WHISPERX
    # -------------------------------------------------------------------------------------------------------
    
    # CÁLCULO DE SCORE PROMEDIO PARA CADA SEGMENTO
    scores = []
    for segment in result["segments"]:
        # Filtrar solo las palabras que tienen un puntaje válido
        words_with_scores = [word for word in segment["words"] if "score" in word]
        # Calcular el puntaje promedio para las palabras filtradas
        if words_with_scores:
            avg_score = pd.DataFrame(words_with_scores)["score"].mean()
        else:
            avg_score = float("nan")  # Otra opción: avg_score = None
        scores.append(avg_score)

        scores = pd.Series(scores, name = "avg_score")
    
    # DATAFRAME DE  DIARIZACION
    diarizacion = pd.DataFrame(result['segments'])

    # DATAFRAME DE DIARIZACION Y SCORE PROMEDIO
    transcription_df = pd.concat([diarizacion, scores], axis = 1)
    return [result, transcription_df]

# %% [markdown]
# # Otros audios

# %%
["1014249230_3.WAV", "1129574339_6.WAV", "14838701_2.WAV"]
# Out:
# ['1014249230_3.WAV', '1129574339_6.WAV', '14838701_2.WAV']

# %%
result_com = transcription("14838701_2.WAV", token = "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", batch_size = 16)
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\usuario\.cache\torch\whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.2+cu118. Bad things might happen unless you revert torch to 1.x.
